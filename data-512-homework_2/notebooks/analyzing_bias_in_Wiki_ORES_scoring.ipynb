# %% [markdown]
# # Article Page Info MediaWiki API Example
# This example illustrates how to access page info data using the [MediaWiki REST API for the EN Wikipedia](https://www.mediawiki.org/wiki/API:Main_page). This example shows how to request summary 'page info' for a single article page. The API documentation, [API:Info](https://www.mediawiki.org/wiki/API:Info), covers additional details that may be helpful when trying to use or understand this example.
#
# ## License
# This code example was developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.1 - August 14, 2023

# %%
# 
# These are standard python modules
import json, time, urllib.parse
#
# The 'requests' module is not a standard Python module. You will need to install this with pip/pip3 if you do not already have it
import requests
import pandas as pd
import os
import csv
import openpyxl
import numpy as np

# %% [markdown]
# The example relies on some constants that help make the code a bit more readable.

# %%
#########
#
#    CONSTANTS
#

# The basic English Wikipedia API endpoint
API_ENWIKIPEDIA_ENDPOINT = "https://en.wikipedia.org/w/api.php"

# We'll assume that there needs to be some throttling for these requests - we should always be nice to a free data resource
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making automated requests we should include something that is unique to the person making the request
# This should include an email - your UW email would be good to put in there
REQUEST_HEADERS = {
    'User-Agent': 'sboral@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2023',
}

# This is just a list of English Wikipedia article titles that we can use for example requests
ARTICLE_TITLES = [ 'Bison', 'Northern flicker', 'Red squirrel', 'Chinook salmon', 'Horseshoe bat' ]

# This is a string of additional page properties that can be returned see the Info documentation for
# what can be included. If you don't want any this can simply be the empty string
PAGEINFO_EXTENDED_PROPERTIES = "talkid|url|watched|watchers"
#PAGEINFO_EXTENDED_PROPERTIES = ""

# This template lists the basic parameters for making this
PAGEINFO_PARAMS_TEMPLATE = {
    "action": "query",
    "format": "json",
    "titles": "",           # to simplify this should be a single page title at a time
    "prop": "info",
    "inprop": PAGEINFO_EXTENDED_PROPERTIES
}

# %% [markdown]
# The API request will be made using one procedure. The idea is to make this reusable. The procedure is parameterized, but relies on the constants above for the important parameters. The underlying assumption is that this will be used to request data for a set of article pages. Therefore the parameter most likely to change is the article_title.

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_pageinfo_per_article(article_title = None, 
                                 endpoint_url = API_ENWIKIPEDIA_ENDPOINT, 
                                 request_template = PAGEINFO_PARAMS_TEMPLATE,
                                 headers = REQUEST_HEADERS):
    
    # article title can be as a parameter to the call or in the request_template
    if article_title:
        request_template['titles'] = article_title

    if not request_template['titles']:
        raise Exception("Must supply an article title to make a pageinfo request.")

    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or any other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(endpoint_url, headers=headers, params=request_template)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# ### Step 1: Data Acquisition

# %% [markdown]
# #### Step 1A: Retrieving and loading article data from Wikipedia for all cities.
# First we will load the cities data into a dataframe.
# Then we will use pass this dataframe to the wikipedia API request function to get details on these cities.

# %%
cities_df=pd.read_csv('/Users/sayo/Documents/Projects/Home-Projects/ScratchPad/us_cities_by_state_SEPT.2023.csv')
cities_df.head(5)
#cities_df['page_title'][1]
# Out:
#      state           page_title  \
# 0  Alabama   Abbeville, Alabama
# 1  Alabama  Adamsville, Alabama
# 2  Alabama     Addison, Alabama
# 3  Alabama       Akron, Alabama
# 4  Alabama   Alabaster, Alabama
#
#                                                  url
# 0   https://en.wikipedia.org/wiki/Abbeville,_Alabama
# 1  https://en.wikipedia.org/wiki/Adamsville,_Alabama
# 2     https://en.wikipedia.org/wiki/Addison,_Alabama
# 3       https://en.wikipedia.org/wiki/Akron,_Alabama
# 4   https://en.wikipedia.org/wiki/Alabaster,_Alabama

# %%
# fetch city data
print(f"Getting page info data for: {cities_df['page_title'][1]}")
info = request_pageinfo_per_article(cities_df['page_title'][1])
print(json.dumps(info['query']['pages'],indent=4))
# Out:
# Getting page info data for: Adamsville, Alabama
# {
#     "104761": {
#         "pageid": 104761,
#         "ns": 0,
#         "title": "Adamsville, Alabama",
#         "contentmodel": "wikitext",
#         "pagelanguage": "en",
#         "pagelanguagehtmlcode": "en",
#         "pagelanguagedir": "ltr",
#         "touched": "2023-10-10T22:35:37Z",
#         "lastrevid": 1177621427,
#         "length": 18040,
#         "talkid": 281272,
#         "fullurl": "https://en.wikipedia.org/wiki/Adamsville,_Alabama",
#         "editurl": "https://en.wikipedia.org/w/index.php?title=Adamsville,_Alabama&action=edit",
#         "canonicalurl": "https://en.wikipedia.org/wiki/Adamsville,_Alabama"
#     }
# }

# %%
# writing data to json file
formatted_view={}
for i in range(len(cities_df)):
    page_title= cities_df['page_title'][i]
    print("Getting page info data for:" ,page_title)
    info = request_pageinfo_per_article(page_title)
    formatted_view[page_title]=(info['query']['pages'])
if os.path.exists('wikipedia_us_city_info.json'):
    os.remove('wikipedia_us_city_info.json')
with open('wikipedia_us_city_info.json','a' ) as file:
    json.dump(formatted_view,file, indent=4)
# Out:
# Getting page info data for: Abbeville, Alabama
# Getting page info data for: Adamsville, Alabama
# Getting page info data for: Addison, Alabama
# Getting page info data for: Akron, Alabama
# Getting page info data for: Alabaster, Alabama
# Getting page info data for: Albertville, Alabama
# Getting page info data for: Alexander City, Alabama
# Getting page info data for: Aliceville, Alabama
# Getting page info data for: Allgood, Alabama
# Getting page info data for: Altoona, Alabama
# Getting page info data for: Andalusia, Alabama
# Getting page info data for: Anderson, Lauderdale County, Alabama
# Getting page info data for: Anniston, Alabama
# Getting page info data for: Arab, Alabama
# Getting page info data for: Ardmore, Alabama
# Getting page info data for: Argo, Alabama
# Getting page info data for: Ariton, Alabama
# Getting page info data for: Arley, Alabama
# Getting page info data for: Ashford, Alabama
# Getting page info data for: Ashland, Alabama
# Getting page info data for: Ashville, Alabama
# Getting page info data for: Athens, Alabama
# Getting page info data for: Atmore, Alabama
# Getting page info data for: Attalla, Alabama
# Getting page info data for: Auburn, Alabama
# Getting page info data for: Autaugaville, Alabama
# Getting page info data for: Avon, Alabama
# Getting page info data for: Babbie, Alabama
# Getting page info data for: Baileyton, Alabama
# Getting page info data for: Bakerhill, Alabama
# Getting page info data for: Banks, Alabama
# Getting page info data for: Bay Minette, Alabama
# Getting page info data for: Bayou La Batre, Alabama
# Getting page info data for: Bear Creek, Alabama
# Getting page info data for: Beatrice, Alabama
# Getting page info data for: Beaverton, Alabama
# Getting page info data for: Belk, Alabama
# Getting page info data for: Benton, Alabama
# Getting page info data for: Berlin, Alabama
# Getting page info data for: Berry, Alabama
# Getting page info data for: Bessemer, Alabama
# Getting page info data for: Billingsley, Alabama
# Getting page info data for: Birmingham, Alabama
# Getting page info data for: Black, Alabama
# Getting page info data for: Blountsville, Alabama
# Getting page info data for: Blue Springs, Alabama
# Getting page info data for: Boaz, Alabama
# Getting page info data for: Boligee, Alabama
# Getting page info data for: Bon Air, Alabama
# Getting page info data for: Brantley, Alabama
# Getting page info data for: Brent, Alabama
# Getting page info data for: Brewton, Alabama
# Getting page info data for: Bridgeport, Alabama
# Getting page info data for: Brighton, Alabama
# Getting page info data for: Brilliant, Alabama
# Getting page info data for: Brookside, Alabama
# Getting page info data for: Brookwood, Alabama
# Getting page info data for: Brundidge, Alabama
# Getting page info data for: Butler, Alabama
# Getting page info data for: Calera, Alabama
# Getting page info data for: Camden, Alabama
# Getting page info data for: Camp Hill, Alabama
# Getting page info data for: Carbon Hill, Alabama
# Getting page info data for: Cardiff, Alabama
# Getting page info data for: Carolina, Alabama
# Getting page info data for: Carrollton, Alabama
# Getting page info data for: Castleberry, Alabama
# Getting page info data for: Cedar Bluff, Alabama
# Getting page info data for: Center Point, Alabama
# Getting page info data for: Centre, Alabama
# Getting page info data for: Centreville, Alabama
# Getting page info data for: Chatom, Alabama
# Getting page info data for: Chelsea, Alabama
# Getting page info data for: Cherokee, Alabama
# Getting page info data for: Chickasaw, Alabama
# Getting page info data for: Childersburg, Alabama
# Getting page info data for: Citronelle, Alabama
# Getting page info data for: Clanton, Alabama
# Getting page info data for: Clay, Alabama
# Getting page info data for: Clayhatchee, Alabama
# Getting page info data for: Clayton, Alabama
# Getting page info data for: Cleveland, Alabama
# Getting page info data for: Clio, Alabama
# Getting page info data for: Coaling, Alabama
# Getting page info data for: Coffee Springs, Alabama
# Getting page info data for: Coffeeville, Alabama
# Getting page info data for: Coker, Alabama
# Getting page info data for: Collinsville, Alabama
# Getting page info data for: Colony, Alabama
# Getting page info data for: Columbia, Alabama
# Getting page info data for: Columbiana, Alabama
# Getting page info data for: Coosada, Alabama
# Getting page info data for: Cordova, Alabama
# Getting page info data for: Cottonwood, Alabama
# Getting page info data for: County Line, Alabama
# Getting page info data for: Courtland, Alabama
# Getting page info data for: Cowarts, Alabama
# Getting page info data for: Creola, Alabama
# Getting page info data for: Crossville, Alabama
# Getting page info data for: Cuba, Alabama
# Getting page info data for: Cullman, Alabama
# Getting page info data for: Cusseta, Alabama
# Getting page info data for: Dadeville, Alabama
# Getting page info data for: Daleville, Alabama
# Getting page info data for: Daphne, Alabama
# Getting page info data for: Dauphin Island, Alabama
# Getting page info data for: Daviston, Alabama
# Getting page info data for: Dayton, Alabama
# Getting page info data for: Deatsville, Alabama
# Getting page info data for: Decatur, Alabama
# Getting page info data for: Demopolis, Alabama
# Getting page info data for: Detroit, Alabama
# Getting page info data for: Dodge City, Alabama
# Getting page info data for: Dora, Alabama
# Getting page info data for: Dothan, Alabama
# Getting page info data for: Double Springs, Alabama
# Getting page info data for: Douglas, Alabama
# Getting page info data for: Dozier, Alabama
# Getting page info data for: Dutton, Alabama
# Getting page info data for: East Brewton, Alabama
# Getting page info data for: Eclectic, Alabama
# Getting page info data for: Edwardsville, Alabama
# Getting page info data for: Elba, Alabama
# Getting page info data for: Elberta, Alabama
# Getting page info data for: Eldridge, Alabama
# Getting page info data for: Elkmont, Alabama
# Getting page info data for: Elmore, Alabama
# Getting page info data for: Emelle, Alabama
# Getting page info data for: Enterprise, Alabama
# Getting page info data for: Epes, Alabama
# Getting page info data for: Ethelsville, Alabama
# Getting page info data for: Eufaula, Alabama
# Getting page info data for: Eutaw, Alabama
# Getting page info data for: Eva, Alabama
# Getting page info data for: Evergreen, Conecuh County, Alabama
# Getting page info data for: Excel, Alabama
# Getting page info data for: Fairfield, Alabama
# Getting page info data for: Fairhope, Alabama
# Getting page info data for: Fairview, Alabama
# Getting page info data for: Falkville, Alabama
# Getting page info data for: Faunsdale, Alabama
# Getting page info data for: Fayette, Alabama
# Getting page info data for: Five Points, Alabama
# Getting page info data for: Flomaton, Alabama
# Getting page info data for: Florala, Alabama
# Getting page info data for: Florence, Alabama
# Getting page info data for: Foley, Alabama
# Getting page info data for: Forkland, Alabama
# Getting page info data for: Fort Deposit, Alabama
# Getting page info data for: Fort Payne, Alabama
# Getting page info data for: Franklin, Alabama
# Getting page info data for: Frisco City, Alabama
# Getting page info data for: Fruithurst, Alabama
# Getting page info data for: Fulton, Alabama
# Getting page info data for: Fultondale, Alabama
# Getting page info data for: Fyffe, Alabama
# Getting page info data for: Gadsden, Alabama
# Getting page info data for: Gainesville, Alabama
# Getting page info data for: Gantt, Alabama
# Getting page info data for: Garden City, Alabama
# Getting page info data for: Gardendale, Alabama
# Getting page info data for: Gaylesville, Alabama
# Getting page info data for: Geiger, Alabama
# Getting page info data for: Geneva, Alabama
# Getting page info data for: Georgiana, Alabama
# Getting page info data for: Geraldine, Alabama
# Getting page info data for: Gilbertown, Alabama
# Getting page info data for: Glen Allen, Alabama
# Getting page info data for: Glencoe, Alabama
# Getting page info data for: Glenwood, Alabama
# Getting page info data for: Goldville, Alabama
# Getting page info data for: Good Hope, Alabama
# Getting page info data for: Goodwater, Alabama
# Getting page info data for: Gordo, Alabama
# Getting page info data for: Gordon, Alabama
# Getting page info data for: Gordonville, Alabama
# Getting page info data for: Goshen, Alabama
# Getting page info data for: Grant, Alabama
# Getting page info data for: Graysville, Alabama
# Getting page info data for: Greensboro, Alabama
# Getting page info data for: Greenville, Alabama
# Getting page info data for: Grimes, Alabama
# Getting page info data for: Grove Hill, Alabama
# Getting page info data for: Guin, Alabama
# Getting page info data for: Gulf Shores, Alabama
# Getting page info data for: Guntersville, Alabama
# Getting page info data for: Gurley, Alabama
# Getting page info data for: Gu-Win, Alabama
# Getting page info data for: Hackleburg, Alabama
# Getting page info data for: Haleburg, Alabama
# Getting page info data for: Haleyville, Alabama
# Getting page info data for: Hamilton, Alabama
# Getting page info data for: Hammondville, Alabama
# Getting page info data for: Hanceville, Alabama
# Getting page info data for: Harpersville, Alabama
# Getting page info data for: Hartford, Alabama
# Getting page info data for: Hartselle, Alabama
# Getting page info data for: Hayden, Alabama
# Getting page info data for: Hayneville, Alabama
# Getting page info data for: Headland, Alabama
# Getting page info data for: Heath, Alabama
# Getting page info data for: Heflin, Alabama
# Getting page info data for: Helena, Alabama
# Getting page info data for: Henagar, Alabama
# Getting page info data for: Highland Lake, Alabama
# Getting page info data for: Hillsboro, Alabama
# Getting page info data for: Hobson City, Alabama
# Getting page info data for: Hodges, Alabama
# Getting page info data for: Hokes Bluff, Alabama
# Getting page info data for: Holly Pond, Alabama
# Getting page info data for: Hollywood, Alabama
# Getting page info data for: Homewood, Alabama
# Getting page info data for: Hoover, Alabama
# Getting page info data for: Horn Hill, Alabama
# Getting page info data for: Hueytown, Alabama
# Getting page info data for: Huntsville, Alabama
# Getting page info data for: Hurtsboro, Alabama
# Getting page info data for: Hytop, Alabama
# Getting page info data for: Ider, Alabama
# Getting page info data for: Indian Springs Village, Alabama
# Getting page info data for: Irondale, Alabama
# Getting page info data for: Jackson, Alabama
# Getting page info data for: Jackson's Gap, Alabama
# Getting page info data for: Jacksonville, Alabama
# Getting page info data for: Jasper, Alabama
# Getting page info data for: Jemison, Alabama
# Getting page info data for: Kansas, Alabama
# Getting page info data for: Kellyton, Alabama
# Getting page info data for: Kennedy, Alabama
# Getting page info data for: Killen, Alabama
# Getting page info data for: Kimberly, Alabama
# Getting page info data for: Kinsey, Alabama
# Getting page info data for: Kinston, Alabama
# Getting page info data for: LaFayette, Alabama
# Getting page info data for: Lake View, Alabama
# Getting page info data for: Lakeview, Alabama
# Getting page info data for: Lanett, Alabama
# Getting page info data for: Langston, Alabama
# Getting page info data for: Leeds, Alabama
# Getting page info data for: Leesburg, Alabama
# Getting page info data for: Leighton, Alabama
# Getting page info data for: Lester, Alabama
# Getting page info data for: Level Plains, Alabama
# Getting page info data for: Lexington, Alabama
# Getting page info data for: Libertyville, Alabama
# Getting page info data for: Lincoln, Alabama
# Getting page info data for: Linden, Alabama
# Getting page info data for: Lineville, Alabama
# Getting page info data for: Lipscomb, Alabama
# Getting page info data for: Lisman, Alabama
# Getting page info data for: Littleville, Alabama
# Getting page info data for: Livingston, Alabama
# Getting page info data for: Loachapoka, Alabama
# Getting page info data for: Lockhart, Alabama
# Getting page info data for: Locust Fork, Alabama
# Getting page info data for: Louisville, Alabama
# Getting page info data for: Lowndesboro, Alabama
# Getting page info data for: Loxley, Alabama
# Getting page info data for: Luverne, Alabama
# Getting page info data for: Lynn, Alabama
# Getting page info data for: Madison, Alabama
# Getting page info data for: Madrid, Alabama
# Getting page info data for: Magnolia Springs, Alabama
# Getting page info data for: Malvern, Alabama
# Getting page info data for: Maplesville, Alabama
# Getting page info data for: Margaret, Alabama
# Getting page info data for: Marion, Alabama
# Getting page info data for: Maytown, Alabama
# Getting page info data for: McIntosh, Alabama
# Getting page info data for: McKenzie, Alabama
# Getting page info data for: McMullen, Alabama
# Getting page info data for: Memphis, Alabama
# Getting page info data for: Mentone, Alabama
# Getting page info data for: Midfield, Alabama
# Getting page info data for: Midland City, Alabama
# Getting page info data for: Midway, Alabama
# Getting page info data for: Millbrook, Alabama
# Getting page info data for: Millport, Alabama
# Getting page info data for: Millry, Alabama
# Getting page info data for: Mobile, Alabama
# Getting page info data for: Monroeville, Alabama
# Getting page info data for: Montevallo, Alabama
# Getting page info data for: Montgomery, Alabama
# Getting page info data for: Moody, Alabama
# Getting page info data for: Mooresville, Alabama
# Getting page info data for: Morris, Alabama
# Getting page info data for: Mosses, Alabama
# Getting page info data for: Moulton, Alabama
# Getting page info data for: Moundville, Alabama
# Getting page info data for: Mount Vernon, Alabama
# Getting page info data for: Mountain Brook, Alabama
# Getting page info data for: Mulga, Alabama
# Getting page info data for: Munford, Alabama
# Getting page info data for: Muscle Shoals, Alabama
# Getting page info data for: Myrtlewood, Alabama
# Getting page info data for: Napier Field, Alabama
# Getting page info data for: Natural Bridge, Alabama
# Getting page info data for: Nauvoo, Alabama
# Getting page info data for: Nectar, Alabama
# Getting page info data for: Needham, Alabama
# Getting page info data for: New Brockton, Alabama
# Getting page info data for: New Hope, Alabama
# Getting page info data for: New Site, Alabama
# Getting page info data for: Newbern, Alabama
# Getting page info data for: Newton, Alabama
# Getting page info data for: Newville, Alabama
# Getting page info data for: North Courtland, Alabama
# Getting page info data for: North Johns, Alabama
# Getting page info data for: Northport, Alabama
# Getting page info data for: Notasulga, Alabama
# Getting page info data for: Oak Grove, Alabama
# Getting page info data for: Oak Hill, Alabama
# Getting page info data for: Oakman, Alabama
# Getting page info data for: Odenville, Alabama
# Getting page info data for: Ohatchee, Alabama
# Getting page info data for: Oneonta, Alabama
# Getting page info data for: Onycha, Alabama
# Getting page info data for: Opelika, Alabama
# Getting page info data for: Opp, Alabama
# Getting page info data for: Orange Beach, Alabama
# Getting page info data for: Orrville, Alabama
# Getting page info data for: Owens Cross Roads, Alabama
# Getting page info data for: Oxford, Alabama
# Getting page info data for: Ozark, Alabama
# Getting page info data for: Paint Rock, Alabama
# Getting page info data for: Parrish, Alabama
# Getting page info data for: Pelham, Alabama
# Getting page info data for: Pell City, Alabama
# Getting page info data for: Pennington, Alabama
# Getting page info data for: Perdido Beach, Alabama
# Getting page info data for: Petrey, Alabama
# Getting page info data for: Phenix City, Alabama
# Getting page info data for: Phil Campbell, Alabama
# Getting page info data for: Pickensville, Alabama
# Getting page info data for: Piedmont, Alabama
# Getting page info data for: Pike Road, Alabama
# Getting page info data for: Pinckard, Alabama
# Getting page info data for: Pine Apple, Alabama
# Getting page info data for: Pine Hill, Alabama
# Getting page info data for: Pine Ridge, Alabama
# Getting page info data for: Pinson, Alabama
# Getting page info data for: Pisgah, Alabama
# Getting page info data for: Pleasant Grove, Alabama
# Getting page info data for: Pleasant Groves, Alabama
# Getting page info data for: Pollard, Alabama
# Getting page info data for: Powell, Alabama
# Getting page info data for: Prattville, Alabama
# Getting page info data for: Priceville, Alabama
# Getting page info data for: Prichard, Alabama
# Getting page info data for: Providence, Alabama
# Getting page info data for: Ragland, Alabama
# Getting page info data for: Rainbow City, Alabama
# Getting page info data for: Rainsville, Alabama
# Getting page info data for: Ranburne, Alabama
# Getting page info data for: Red Bay, Alabama
# Getting page info data for: Red Level, Alabama
# Getting page info data for: Reece City, Alabama
# Getting page info data for: Reform, Alabama
# Getting page info data for: Rehobeth, Alabama
# Getting page info data for: Repton, Alabama
# Getting page info data for: Ridgeville, Alabama
# Getting page info data for: River Falls, Alabama
# Getting page info data for: Riverside, Alabama
# Getting page info data for: Riverview, Alabama
# Getting page info data for: Roanoke, Alabama
# Getting page info data for: Robertsdale, Alabama
# Getting page info data for: Rockford, Alabama
# Getting page info data for: Rogersville, Alabama
# Getting page info data for: Rosa, Alabama
# Getting page info data for: Russellville, Alabama
# Getting page info data for: Rutledge, Alabama
# Getting page info data for: St. Florian, Alabama
# Getting page info data for: Samson, Alabama
# Getting page info data for: Sand Rock, Alabama
# Getting page info data for: Sanford, Alabama
# Getting page info data for: Saraland, Alabama
# Getting page info data for: Sardis City, Alabama
# Getting page info data for: Satsuma, Alabama
# Getting page info data for: Scottsboro, Alabama
# Getting page info data for: Section, Alabama
# Getting page info data for: Selma, Alabama
# Getting page info data for: Sheffield, Alabama
# Getting page info data for: Shiloh, DeKalb County, Alabama
# Getting page info data for: Shorter, Alabama
# Getting page info data for: Silas, Alabama
# Getting page info data for: Silverhill, Alabama
# Getting page info data for: Sipsey, Alabama
# Getting page info data for: Skyline, Alabama
# Getting page info data for: Slocomb, Alabama
# Getting page info data for: Smiths Station, Alabama
# Getting page info data for: Snead, Alabama
# Getting page info data for: Somerville, Alabama
# Getting page info data for: South Vinemont, Alabama
# Getting page info data for: Southside, Alabama
# Getting page info data for: Spanish Fort, Alabama
# Getting page info data for: Springville, Alabama
# Getting page info data for: Steele, Alabama
# Getting page info data for: Stevenson, Alabama
# Getting page info data for: Sulligent, Alabama
# Getting page info data for: Sumiton, Alabama
# Getting page info data for: Summerdale, Alabama
# Getting page info data for: Susan Moore, Alabama
# Getting page info data for: Sweet Water, Alabama
# Getting page info data for: Sylacauga, Alabama
# Getting page info data for: Sylvan Springs, Alabama
# Getting page info data for: Sylvania, Alabama
# Getting page info data for: Talladega Springs, Alabama
# Getting page info data for: Talladega, Alabama
# Getting page info data for: Tallassee, Alabama
# Getting page info data for: Tarrant, Alabama
# Getting page info data for: Taylor, Alabama
# Getting page info data for: Thomaston, Alabama
# Getting page info data for: Thomasville, Alabama
# Getting page info data for: Thorsby, Alabama
# Getting page info data for: Town Creek, Alabama
# Getting page info data for: Toxey, Alabama
# Getting page info data for: Trafford, Alabama
# Getting page info data for: Triana, Alabama
# Getting page info data for: Trinity, Alabama
# Getting page info data for: Troy, Alabama
# Getting page info data for: Trussville, Alabama
# Getting page info data for: Tuscaloosa, Alabama
# Getting page info data for: Tuscumbia, Alabama
# Getting page info data for: Tuskegee, Alabama
# Getting page info data for: Twin, Alabama
# Getting page info data for: Union Grove, Alabama
# Getting page info data for: Union Springs, Alabama
# Getting page info data for: Union, Alabama
# Getting page info data for: Uniontown, Alabama
# Getting page info data for: Valley, Alabama
# Getting page info data for: Valley Grande, Alabama
# Getting page info data for: Valley Head, Alabama
# Getting page info data for: Vance, Alabama
# Getting page info data for: Vernon, Alabama
# Getting page info data for: Vestavia Hills, Alabama
# Getting page info data for: Vina, Alabama
# Getting page info data for: Vincent, Alabama
# Getting page info data for: Vredenburgh, Alabama
# Getting page info data for: Wadley, Alabama
# Getting page info data for: Waldo, Alabama
# Getting page info data for: Walnut Grove, Alabama
# Getting page info data for: Warrior, Alabama
# Getting page info data for: Waterloo, Alabama
# Getting page info data for: Waverly, Alabama
# Getting page info data for: Weaver, Alabama
# Getting page info data for: Webb, Alabama
# Getting page info data for: Wedowee, Alabama
# Getting page info data for: West Blocton, Alabama
# Getting page info data for: West Jefferson, Alabama
# Getting page info data for: West Point, Alabama
# Getting page info data for: Westover, Alabama
# Getting page info data for: Wetumpka, Alabama
# Getting page info data for: White Hall, Alabama
# Getting page info data for: Wilsonville, Alabama
# Getting page info data for: Wilton, Alabama
# Getting page info data for: Winfield, Alabama
# Getting page info data for: Woodland, Alabama
# Getting page info data for: Woodstock, Alabama
# Getting page info data for: Woodville, Alabama
# Getting page info data for: Yellow Bluff, Alabama
# Getting page info data for: York, Alabama
# Getting page info data for: Abbeville, Alabama
# Getting page info data for: Adamsville, Alabama
# Getting page info data for: Addison, Alabama
# Getting page info data for: Akron, Alabama
# Getting page info data for: Alabaster, Alabama
# Getting page info data for: Albertville, Alabama
# Getting page info data for: Alexander City, Alabama
# Getting page info data for: Aliceville, Alabama
# Getting page info data for: Allgood, Alabama
# Getting page info data for: Altoona, Alabama
# Getting page info data for: Andalusia, Alabama
# Getting page info data for: Anderson, Lauderdale County, Alabama
# Getting page info data for: Anniston, Alabama
# Getting page info data for: Arab, Alabama
# Getting page info data for: Ardmore, Alabama
# Getting page info data for: Argo, Alabama
# Getting page info data for: Ariton, Alabama
# Getting page info data for: Arley, Alabama
# Getting page info data for: Ashford, Alabama
# Getting page info data for: Ashland, Alabama
# Getting page info data for: Ashville, Alabama
# Getting page info data for: Athens, Alabama
# Getting page info data for: Atmore, Alabama
# Getting page info data for: Attalla, Alabama
# Getting page info data for: Auburn, Alabama
# Getting page info data for: Autaugaville, Alabama
# Getting page info data for: Avon, Alabama
# Getting page info data for: Babbie, Alabama
# Getting page info data for: Baileyton, Alabama
# Getting page info data for: Bakerhill, Alabama
# Getting page info data for: Banks, Alabama
# Getting page info data for: Bay Minette, Alabama
# Getting page info data for: Bayou La Batre, Alabama
# Getting page info data for: Bear Creek, Alabama
# Getting page info data for: Beatrice, Alabama
# Getting page info data for: Beaverton, Alabama
# Getting page info data for: Belk, Alabama
# Getting page info data for: Benton, Alabama
# Getting page info data for: Berlin, Alabama
# Getting page info data for: Berry, Alabama
# Getting page info data for: Bessemer, Alabama
# Getting page info data for: Billingsley, Alabama
# Getting page info data for: Birmingham, Alabama
# Getting page info data for: Black, Alabama
# Getting page info data for: Blountsville, Alabama
# Getting page info data for: Blue Springs, Alabama
# Getting page info data for: Boaz, Alabama
# Getting page info data for: Boligee, Alabama
# Getting page info data for: Bon Air, Alabama
# Getting page info data for: Brantley, Alabama
# Getting page info data for: Brent, Alabama
# Getting page info data for: Brewton, Alabama
# Getting page info data for: Bridgeport, Alabama
# Getting page info data for: Brighton, Alabama
# Getting page info data for: Brilliant, Alabama
# Getting page info data for: Brookside, Alabama
# Getting page info data for: Brookwood, Alabama
# Getting page info data for: Brundidge, Alabama
# Getting page info data for: Butler, Alabama
# Getting page info data for: Calera, Alabama
# Getting page info data for: Camden, Alabama
# Getting page info data for: Camp Hill, Alabama
# Getting page info data for: Carbon Hill, Alabama
# Getting page info data for: Cardiff, Alabama
# Getting page info data for: Carolina, Alabama
# Getting page info data for: Carrollton, Alabama
# Getting page info data for: Castleberry, Alabama
# Getting page info data for: Cedar Bluff, Alabama
# Getting page info data for: Center Point, Alabama
# Getting page info data for: Centre, Alabama
# Getting page info data for: Centreville, Alabama
# Getting page info data for: Chatom, Alabama
# Getting page info data for: Chelsea, Alabama
# Getting page info data for: Cherokee, Alabama
# Getting page info data for: Chickasaw, Alabama
# Getting page info data for: Childersburg, Alabama
# Getting page info data for: Citronelle, Alabama
# Getting page info data for: Clanton, Alabama
# Getting page info data for: Clay, Alabama
# Getting page info data for: Clayhatchee, Alabama
# Getting page info data for: Clayton, Alabama
# Getting page info data for: Cleveland, Alabama
# Getting page info data for: Clio, Alabama
# Getting page info data for: Coaling, Alabama
# Getting page info data for: Coffee Springs, Alabama
# Getting page info data for: Coffeeville, Alabama
# Getting page info data for: Coker, Alabama
# Getting page info data for: Collinsville, Alabama
# Getting page info data for: Colony, Alabama
# Getting page info data for: Columbia, Alabama
# Getting page info data for: Columbiana, Alabama
# Getting page info data for: Coosada, Alabama
# Getting page info data for: Cordova, Alabama
# Getting page info data for: Cottonwood, Alabama
# Getting page info data for: County Line, Alabama
# Getting page info data for: Courtland, Alabama
# Getting page info data for: Cowarts, Alabama
# Getting page info data for: Creola, Alabama
# Getting page info data for: Crossville, Alabama
# Getting page info data for: Cuba, Alabama
# Getting page info data for: Cullman, Alabama
# Getting page info data for: Cusseta, Alabama
# Getting page info data for: Dadeville, Alabama
# Getting page info data for: Daleville, Alabama
# Getting page info data for: Daphne, Alabama
# Getting page info data for: Dauphin Island, Alabama
# Getting page info data for: Daviston, Alabama
# Getting page info data for: Dayton, Alabama
# Getting page info data for: Deatsville, Alabama
# Getting page info data for: Decatur, Alabama
# Getting page info data for: Demopolis, Alabama
# Getting page info data for: Detroit, Alabama
# Getting page info data for: Dodge City, Alabama
# Getting page info data for: Dora, Alabama
# Getting page info data for: Dothan, Alabama
# Getting page info data for: Double Springs, Alabama
# Getting page info data for: Douglas, Alabama
# Getting page info data for: Dozier, Alabama
# Getting page info data for: Dutton, Alabama
# Getting page info data for: East Brewton, Alabama
# Getting page info data for: Eclectic, Alabama
# Getting page info data for: Edwardsville, Alabama
# Getting page info data for: Elba, Alabama
# Getting page info data for: Elberta, Alabama
# Getting page info data for: Eldridge, Alabama
# Getting page info data for: Elkmont, Alabama
# Getting page info data for: Elmore, Alabama
# Getting page info data for: Emelle, Alabama
# Getting page info data for: Enterprise, Alabama
# Getting page info data for: Epes, Alabama
# Getting page info data for: Ethelsville, Alabama
# Getting page info data for: Eufaula, Alabama
# Getting page info data for: Eutaw, Alabama
# Getting page info data for: Eva, Alabama
# Getting page info data for: Evergreen, Conecuh County, Alabama
# Getting page info data for: Excel, Alabama
# Getting page info data for: Fairfield, Alabama
# Getting page info data for: Fairhope, Alabama
# Getting page info data for: Fairview, Alabama
# Getting page info data for: Falkville, Alabama
# Getting page info data for: Faunsdale, Alabama
# Getting page info data for: Fayette, Alabama
# Getting page info data for: Five Points, Alabama
# Getting page info data for: Flomaton, Alabama
# Getting page info data for: Florala, Alabama
# Getting page info data for: Florence, Alabama
# Getting page info data for: Foley, Alabama
# Getting page info data for: Forkland, Alabama
# Getting page info data for: Fort Deposit, Alabama
# Getting page info data for: Fort Payne, Alabama
# Getting page info data for: Franklin, Alabama
# Getting page info data for: Frisco City, Alabama
# Getting page info data for: Fruithurst, Alabama
# Getting page info data for: Fulton, Alabama
# Getting page info data for: Fultondale, Alabama
# Getting page info data for: Fyffe, Alabama
# Getting page info data for: Gadsden, Alabama
# Getting page info data for: Gainesville, Alabama
# Getting page info data for: Gantt, Alabama
# Getting page info data for: Garden City, Alabama
# Getting page info data for: Gardendale, Alabama
# Getting page info data for: Gaylesville, Alabama
# Getting page info data for: Geiger, Alabama
# Getting page info data for: Geneva, Alabama
# Getting page info data for: Georgiana, Alabama
# Getting page info data for: Geraldine, Alabama
# Getting page info data for: Gilbertown, Alabama
# Getting page info data for: Glen Allen, Alabama
# Getting page info data for: Glencoe, Alabama
# Getting page info data for: Glenwood, Alabama
# Getting page info data for: Goldville, Alabama
# Getting page info data for: Good Hope, Alabama
# Getting page info data for: Goodwater, Alabama
# Getting page info data for: Gordo, Alabama
# Getting page info data for: Gordon, Alabama
# Getting page info data for: Gordonville, Alabama
# Getting page info data for: Goshen, Alabama
# Getting page info data for: Grant, Alabama
# Getting page info data for: Graysville, Alabama
# Getting page info data for: Greensboro, Alabama
# Getting page info data for: Greenville, Alabama
# Getting page info data for: Grimes, Alabama
# Getting page info data for: Grove Hill, Alabama
# Getting page info data for: Guin, Alabama
# Getting page info data for: Gulf Shores, Alabama
# Getting page info data for: Guntersville, Alabama
# Getting page info data for: Gurley, Alabama
# Getting page info data for: Gu-Win, Alabama
# Getting page info data for: Hackleburg, Alabama
# Getting page info data for: Haleburg, Alabama
# Getting page info data for: Haleyville, Alabama
# Getting page info data for: Hamilton, Alabama
# Getting page info data for: Hammondville, Alabama
# Getting page info data for: Hanceville, Alabama
# Getting page info data for: Harpersville, Alabama
# Getting page info data for: Hartford, Alabama
# Getting page info data for: Hartselle, Alabama
# Getting page info data for: Hayden, Alabama
# Getting page info data for: Hayneville, Alabama
# Getting page info data for: Headland, Alabama
# Getting page info data for: Heath, Alabama
# Getting page info data for: Heflin, Alabama
# Getting page info data for: Helena, Alabama
# Getting page info data for: Henagar, Alabama
# Getting page info data for: Highland Lake, Alabama
# Getting page info data for: Hillsboro, Alabama
# Getting page info data for: Hobson City, Alabama
# Getting page info data for: Hodges, Alabama
# Getting page info data for: Hokes Bluff, Alabama
# Getting page info data for: Holly Pond, Alabama
# Getting page info data for: Hollywood, Alabama
# Getting page info data for: Homewood, Alabama
# Getting page info data for: Hoover, Alabama
# Getting page info data for: Horn Hill, Alabama
# Getting page info data for: Hueytown, Alabama
# Getting page info data for: Huntsville, Alabama
# Getting page info data for: Hurtsboro, Alabama
# Getting page info data for: Hytop, Alabama
# Getting page info data for: Ider, Alabama
# Getting page info data for: Indian Springs Village, Alabama
# Getting page info data for: Irondale, Alabama
# Getting page info data for: Jackson, Alabama
# Getting page info data for: Jackson's Gap, Alabama
# Getting page info data for: Jacksonville, Alabama
# Getting page info data for: Jasper, Alabama
# Getting page info data for: Jemison, Alabama
# Getting page info data for: Kansas, Alabama
# Getting page info data for: Kellyton, Alabama
# Getting page info data for: Kennedy, Alabama
# Getting page info data for: Killen, Alabama
# Getting page info data for: Kimberly, Alabama
# Getting page info data for: Kinsey, Alabama
# Getting page info data for: Kinston, Alabama
# Getting page info data for: LaFayette, Alabama
# Getting page info data for: Lake View, Alabama
# Getting page info data for: Lakeview, Alabama
# Getting page info data for: Lanett, Alabama
# Getting page info data for: Langston, Alabama
# Getting page info data for: Leeds, Alabama
# Getting page info data for: Leesburg, Alabama
# Getting page info data for: Leighton, Alabama
# Getting page info data for: Lester, Alabama
# Getting page info data for: Level Plains, Alabama
# Getting page info data for: Lexington, Alabama
# Getting page info data for: Libertyville, Alabama
# Getting page info data for: Lincoln, Alabama
# Getting page info data for: Linden, Alabama
# Getting page info data for: Lineville, Alabama
# Getting page info data for: Lipscomb, Alabama
# Getting page info data for: Lisman, Alabama
# Getting page info data for: Littleville, Alabama
# Getting page info data for: Livingston, Alabama
# Getting page info data for: Loachapoka, Alabama
# Getting page info data for: Lockhart, Alabama
# Getting page info data for: Locust Fork, Alabama
# Getting page info data for: Louisville, Alabama
# Getting page info data for: Lowndesboro, Alabama
# Getting page info data for: Loxley, Alabama
# Getting page info data for: Luverne, Alabama
# Getting page info data for: Lynn, Alabama
# Getting page info data for: Madison, Alabama
# Getting page info data for: Madrid, Alabama
# Getting page info data for: Magnolia Springs, Alabama
# Getting page info data for: Malvern, Alabama
# Getting page info data for: Maplesville, Alabama
# Getting page info data for: Margaret, Alabama
# Getting page info data for: Marion, Alabama
# Getting page info data for: Maytown, Alabama
# Getting page info data for: McIntosh, Alabama
# Getting page info data for: McKenzie, Alabama
# Getting page info data for: McMullen, Alabama
# Getting page info data for: Memphis, Alabama
# Getting page info data for: Mentone, Alabama
# Getting page info data for: Midfield, Alabama
# Getting page info data for: Midland City, Alabama
# Getting page info data for: Midway, Alabama
# Getting page info data for: Millbrook, Alabama
# Getting page info data for: Millport, Alabama
# Getting page info data for: Millry, Alabama
# Getting page info data for: Mobile, Alabama
# Getting page info data for: Monroeville, Alabama
# Getting page info data for: Montevallo, Alabama
# Getting page info data for: Montgomery, Alabama
# Getting page info data for: Moody, Alabama
# Getting page info data for: Mooresville, Alabama
# Getting page info data for: Morris, Alabama
# Getting page info data for: Mosses, Alabama
# Getting page info data for: Moulton, Alabama
# Getting page info data for: Moundville, Alabama
# Getting page info data for: Mount Vernon, Alabama
# Getting page info data for: Mountain Brook, Alabama
# Getting page info data for: Mulga, Alabama
# Getting page info data for: Munford, Alabama
# Getting page info data for: Muscle Shoals, Alabama
# Getting page info data for: Myrtlewood, Alabama
# Getting page info data for: Napier Field, Alabama
# Getting page info data for: Natural Bridge, Alabama
# Getting page info data for: Nauvoo, Alabama
# Getting page info data for: Nectar, Alabama
# Getting page info data for: Needham, Alabama
# Getting page info data for: New Brockton, Alabama
# Getting page info data for: New Hope, Alabama
# Getting page info data for: New Site, Alabama
# Getting page info data for: Newbern, Alabama
# Getting page info data for: Newton, Alabama
# Getting page info data for: Newville, Alabama
# Getting page info data for: North Courtland, Alabama
# Getting page info data for: North Johns, Alabama
# Getting page info data for: Northport, Alabama
# Getting page info data for: Notasulga, Alabama
# Getting page info data for: Oak Grove, Alabama
# Getting page info data for: Oak Hill, Alabama
# Getting page info data for: Oakman, Alabama
# Getting page info data for: Odenville, Alabama
# Getting page info data for: Ohatchee, Alabama
# Getting page info data for: Oneonta, Alabama
# Getting page info data for: Onycha, Alabama
# Getting page info data for: Opelika, Alabama
# Getting page info data for: Opp, Alabama
# Getting page info data for: Orange Beach, Alabama
# Getting page info data for: Orrville, Alabama
# Getting page info data for: Owens Cross Roads, Alabama
# Getting page info data for: Oxford, Alabama
# Getting page info data for: Ozark, Alabama
# Getting page info data for: Paint Rock, Alabama
# Getting page info data for: Parrish, Alabama
# Getting page info data for: Pelham, Alabama
# Getting page info data for: Pell City, Alabama
# Getting page info data for: Pennington, Alabama
# Getting page info data for: Perdido Beach, Alabama
# Getting page info data for: Petrey, Alabama
# Getting page info data for: Phenix City, Alabama
# Getting page info data for: Phil Campbell, Alabama
# Getting page info data for: Pickensville, Alabama
# Getting page info data for: Piedmont, Alabama
# Getting page info data for: Pike Road, Alabama
# Getting page info data for: Pinckard, Alabama
# Getting page info data for: Pine Apple, Alabama
# Getting page info data for: Pine Hill, Alabama
# Getting page info data for: Pine Ridge, Alabama
# Getting page info data for: Pinson, Alabama
# Getting page info data for: Pisgah, Alabama
# Getting page info data for: Pleasant Grove, Alabama
# Getting page info data for: Pleasant Groves, Alabama
# Getting page info data for: Pollard, Alabama
# Getting page info data for: Powell, Alabama
# Getting page info data for: Prattville, Alabama
# Getting page info data for: Priceville, Alabama
# Getting page info data for: Prichard, Alabama
# Getting page info data for: Providence, Alabama
# Getting page info data for: Ragland, Alabama
# Getting page info data for: Rainbow City, Alabama
# Getting page info data for: Rainsville, Alabama
# Getting page info data for: Ranburne, Alabama
# Getting page info data for: Red Bay, Alabama
# Getting page info data for: Red Level, Alabama
# Getting page info data for: Reece City, Alabama
# Getting page info data for: Reform, Alabama
# Getting page info data for: Rehobeth, Alabama
# Getting page info data for: Repton, Alabama
# Getting page info data for: Ridgeville, Alabama
# Getting page info data for: River Falls, Alabama
# Getting page info data for: Riverside, Alabama
# Getting page info data for: Riverview, Alabama
# Getting page info data for: Roanoke, Alabama
# Getting page info data for: Robertsdale, Alabama
# Getting page info data for: Rockford, Alabama
# Getting page info data for: Rogersville, Alabama
# Getting page info data for: Rosa, Alabama
# Getting page info data for: Russellville, Alabama
# Getting page info data for: Rutledge, Alabama
# Getting page info data for: St. Florian, Alabama
# Getting page info data for: Samson, Alabama
# Getting page info data for: Sand Rock, Alabama
# Getting page info data for: Sanford, Alabama
# Getting page info data for: Saraland, Alabama
# Getting page info data for: Sardis City, Alabama
# Getting page info data for: Satsuma, Alabama
# Getting page info data for: Scottsboro, Alabama
# Getting page info data for: Section, Alabama
# Getting page info data for: Selma, Alabama
# Getting page info data for: Sheffield, Alabama
# Getting page info data for: Shiloh, DeKalb County, Alabama
# Getting page info data for: Shorter, Alabama
# Getting page info data for: Silas, Alabama
# Getting page info data for: Silverhill, Alabama
# Getting page info data for: Sipsey, Alabama
# Getting page info data for: Skyline, Alabama
# Getting page info data for: Slocomb, Alabama
# Getting page info data for: Smiths Station, Alabama
# Getting page info data for: Snead, Alabama
# Getting page info data for: Somerville, Alabama
# Getting page info data for: South Vinemont, Alabama
# Getting page info data for: Southside, Alabama
# Getting page info data for: Spanish Fort, Alabama
# Getting page info data for: Springville, Alabama
# Getting page info data for: Steele, Alabama
# Getting page info data for: Stevenson, Alabama
# Getting page info data for: Sulligent, Alabama
# Getting page info data for: Sumiton, Alabama
# Getting page info data for: Summerdale, Alabama
# Getting page info data for: Susan Moore, Alabama
# Getting page info data for: Sweet Water, Alabama
# Getting page info data for: Sylacauga, Alabama
# Getting page info data for: Sylvan Springs, Alabama
# Getting page info data for: Sylvania, Alabama
# Getting page info data for: Talladega Springs, Alabama
# Getting page info data for: Talladega, Alabama
# Getting page info data for: Tallassee, Alabama
# Getting page info data for: Tarrant, Alabama
# Getting page info data for: Taylor, Alabama
# Getting page info data for: Thomaston, Alabama
# Getting page info data for: Thomasville, Alabama
# Getting page info data for: Thorsby, Alabama
# Getting page info data for: Town Creek, Alabama
# Getting page info data for: Toxey, Alabama
# Getting page info data for: Trafford, Alabama
# Getting page info data for: Triana, Alabama
# Getting page info data for: Trinity, Alabama
# Getting page info data for: Troy, Alabama
# Getting page info data for: Trussville, Alabama
# Getting page info data for: Tuscaloosa, Alabama
# Getting page info data for: Tuscumbia, Alabama
# Getting page info data for: Tuskegee, Alabama
# Getting page info data for: Twin, Alabama
# Getting page info data for: Union Grove, Alabama
# Getting page info data for: Union Springs, Alabama
# Getting page info data for: Union, Alabama
# Getting page info data for: Uniontown, Alabama
# Getting page info data for: Valley, Alabama
# Getting page info data for: Valley Grande, Alabama
# Getting page info data for: Valley Head, Alabama
# Getting page info data for: Vance, Alabama
# Getting page info data for: Vernon, Alabama
# Getting page info data for: Vestavia Hills, Alabama
# Getting page info data for: Vina, Alabama
# Getting page info data for: Vincent, Alabama
# Getting page info data for: Vredenburgh, Alabama
# Getting page info data for: Wadley, Alabama
# Getting page info data for: Waldo, Alabama
# Getting page info data for: Walnut Grove, Alabama
# Getting page info data for: Warrior, Alabama
# Getting page info data for: Waterloo, Alabama
# Getting page info data for: Waverly, Alabama
# Getting page info data for: Weaver, Alabama
# Getting page info data for: Webb, Alabama
# Getting page info data for: Wedowee, Alabama
# Getting page info data for: West Blocton, Alabama
# Getting page info data for: West Jefferson, Alabama
# Getting page info data for: West Point, Alabama
# Getting page info data for: Westover, Alabama
# Getting page info data for: Wetumpka, Alabama
# Getting page info data for: White Hall, Alabama
# Getting page info data for: Wilsonville, Alabama
# Getting page info data for: Wilton, Alabama
# Getting page info data for: Winfield, Alabama
# Getting page info data for: Woodland, Alabama
# Getting page info data for: Woodstock, Alabama
# Getting page info data for: Woodville, Alabama
# Getting page info data for: Yellow Bluff, Alabama
# Getting page info data for: York, Alabama
# Getting page info data for: Adak, Alaska
# Getting page info data for: Akhiok, Alaska
# Getting page info data for: Akiak, Alaska
# Getting page info data for: Akutan, Alaska
# Getting page info data for: Alakanuk, Alaska
# Getting page info data for: Aleknagik, Alaska
# Getting page info data for: Allakaket, Alaska
# Getting page info data for: Ambler, Alaska
# Getting page info data for: Anaktuvuk Pass, Alaska
# Getting page info data for: Anchorage, Alaska
# Getting page info data for: Anderson, Alaska
# Getting page info data for: Angoon, Alaska
# Getting page info data for: Aniak, Alaska
# Getting page info data for: Anvik, Alaska
# Getting page info data for: Atka, Alaska
# Getting page info data for: Atqasuk, Alaska
# Getting page info data for: Bethel, Alaska
# Getting page info data for: Bettles, Alaska
# Getting page info data for: Brevig Mission, Alaska
# Getting page info data for: Buckland, Alaska
# Getting page info data for: Chefornak, Alaska
# Getting page info data for: Chevak, Alaska
# Getting page info data for: Chignik, Alaska
# Getting page info data for: Chuathbaluk, Alaska
# Getting page info data for: Clark's Point, Alaska
# Getting page info data for: Coffman Cove, Alaska
# Getting page info data for: Cold Bay, Alaska
# Getting page info data for: Cordova, Alaska
# Getting page info data for: Craig, Alaska
# Getting page info data for: Deering, Alaska
# Getting page info data for: Delta Junction, Alaska
# Getting page info data for: Dillingham, Alaska
# Getting page info data for: Diomede, Alaska
# Getting page info data for: Eagle, Alaska
# Getting page info data for: Edna Bay, Alaska
# Getting page info data for: Eek, Alaska
# Getting page info data for: Egegik, Alaska
# Getting page info data for: Ekwok, Alaska
# Getting page info data for: Elim, Alaska
# Getting page info data for: Emmonak, Alaska
# Getting page info data for: Fairbanks, Alaska
# Getting page info data for: False Pass, Alaska
# Getting page info data for: Fort Yukon, Alaska
# Getting page info data for: Galena, Alaska
# Getting page info data for: Gambell, Alaska
# Getting page info data for: Golovin, Alaska
# Getting page info data for: Goodnews Bay, Alaska
# Getting page info data for: Grayling, Alaska
# Getting page info data for: Gustavus, Alaska
# Getting page info data for: Holy Cross, Alaska
# Getting page info data for: Homer, Alaska
# Getting page info data for: Hoonah, Alaska
# Getting page info data for: Hooper Bay, Alaska
# Getting page info data for: Houston, Alaska
# Getting page info data for: Hughes, Alaska
# Getting page info data for: Huslia, Alaska
# Getting page info data for: Hydaburg, Alaska
# Getting page info data for: Juneau, Alaska
# Getting page info data for: Kachemak, Alaska
# Getting page info data for: Kake, Alaska
# Getting page info data for: Kaktovik, Alaska
# Getting page info data for: Kaltag, Alaska
# Getting page info data for: Kasaan, Alaska
# Getting page info data for: Kenai, Alaska
# Getting page info data for: Ketchikan, Alaska
# Getting page info data for: Kiana, Alaska
# Getting page info data for: King Cove, Alaska
# Getting page info data for: Kivalina, Alaska
# Getting page info data for: Klawock, Alaska
# Getting page info data for: Kobuk, Alaska
# Getting page info data for: Kodiak, Alaska
# Getting page info data for: Kotlik, Alaska
# Getting page info data for: Kotzebue, Alaska
# Getting page info data for: Koyuk, Alaska
# Getting page info data for: Koyukuk, Alaska
# Getting page info data for: Kupreanof, Alaska
# Getting page info data for: Kwethluk, Alaska
# Getting page info data for: Larsen Bay, Alaska
# Getting page info data for: Lower Kalskag, Alaska
# Getting page info data for: Manokotak, Alaska
# Getting page info data for: Marshall, Alaska
# Getting page info data for: McGrath, Alaska
# Getting page info data for: Mekoryuk, Alaska
# Getting page info data for: Mountain Village, Alaska
# Getting page info data for: Napakiak, Alaska
# Getting page info data for: Napaskiak, Alaska
# Getting page info data for: Nenana, Alaska
# Getting page info data for: New Stuyahok, Alaska
# Getting page info data for: Newhalen, Alaska
# Getting page info data for: Nightmute, Alaska
# Getting page info data for: Nikolai, Alaska
# Getting page info data for: Nome, Alaska
# Getting page info data for: Nondalton, Alaska
# Getting page info data for: Noorvik, Alaska
# Getting page info data for: North Pole, Alaska
# Getting page info data for: Nuiqsut, Alaska
# Getting page info data for: Nulato, Alaska
# Getting page info data for: Nunam Iqua, Alaska
# Getting page info data for: Nunapitchuk, Alaska
# Getting page info data for: Old Harbor, Alaska
# Getting page info data for: Ouzinkie, Alaska
# Getting page info data for: Palmer, Alaska
# Getting page info data for: Pelican, Alaska
# Getting page info data for: Pilot Point, Alaska
# Getting page info data for: Pilot Station, Alaska
# Getting page info data for: Platinum, Alaska
# Getting page info data for: Point Hope, Alaska
# Getting page info data for: Port Alexander, Alaska
# Getting page info data for: Port Heiden, Alaska
# Getting page info data for: Port Lions, Alaska
# Getting page info data for: Quinhagak, Alaska
# Getting page info data for: Ruby, Alaska
# Getting page info data for: Russian Mission, Alaska
# ...
# Getting page info data for: Northfork, West Virginia
# Getting page info data for: Ellenboro, West Virginia
# Getting page info data for: Hillsboro, West Virginia
# Getting page info data for: Henderson, West Virginia
# Getting page info data for: Davy, West Virginia
# Getting page info data for: Hendricks, West Virginia
# Getting page info data for: Handley, West Virginia
# Getting page info data for: Bradshaw, West Virginia
# Getting page info data for: Quinwood, West Virginia
# Getting page info data for: Hambleton, West Virginia
# Getting page info data for: Elk Garden, West Virginia
# Getting page info data for: Bayard, West Virginia
# Getting page info data for: Womelsdorf (Coalton), West Virginia
# Getting page info data for: Keystone, West Virginia
# Getting page info data for: Worthington, West Virginia
# Getting page info data for: Sand Fork, West Virginia
# Getting page info data for: Anawalt, West Virginia
# Getting page info data for: Cairo, West Virginia
# Getting page info data for: Matoaka, West Virginia
# Getting page info data for: Falling Spring, West Virginia
# Getting page info data for: Huttonsville, West Virginia
# Getting page info data for: Sylvester, West Virginia
# Getting page info data for: Kimball, West Virginia
# Getting page info data for: Reedy, West Virginia
# Getting page info data for: Montrose, West Virginia
# Getting page info data for: Brandonville, West Virginia
# Getting page info data for: Oakvale, West Virginia
# Getting page info data for: Rhodell, West Virginia
# Getting page info data for: Leon, West Virginia
# Getting page info data for: Pax, West Virginia
# Getting page info data for: Pullman, West Virginia
# Getting page info data for: Camden-on-Gauley, West Virginia
# Getting page info data for: Blacksville, West Virginia
# Getting page info data for: Smithfield, West Virginia
# Getting page info data for: Friendly, West Virginia
# Getting page info data for: Harman, West Virginia
# Getting page info data for: Auburn, West Virginia
# Getting page info data for: Bruceton Mills, West Virginia
# Getting page info data for: Thurmond, West Virginia
# Getting page info data for: County (United States)
# Getting page info data for: Abbotsford, Wisconsin
# Getting page info data for: Adams, Wisconsin
# Getting page info data for: Algoma, Wisconsin
# Getting page info data for: Alma, Wisconsin
# Getting page info data for: Altoona, Wisconsin
# Getting page info data for: Amery, Wisconsin
# Getting page info data for: Antigo, Wisconsin
# Getting page info data for: Appleton, Wisconsin
# Getting page info data for: Arcadia, Wisconsin
# Getting page info data for: Ashland, Wisconsin
# Getting page info data for: Augusta, Wisconsin
# Getting page info data for: Baraboo, Wisconsin
# Getting page info data for: Barron, Wisconsin
# Getting page info data for: Bayfield, Wisconsin
# Getting page info data for: Beaver Dam, Wisconsin
# Getting page info data for: Beloit, Wisconsin
# Getting page info data for: Berlin, Wisconsin
# Getting page info data for: Black River Falls, Wisconsin
# Getting page info data for: Blair, Wisconsin
# Getting page info data for: Bloomer, Wisconsin
# Getting page info data for: Boscobel, Wisconsin
# Getting page info data for: Brillion, Wisconsin
# Getting page info data for: Brodhead, Wisconsin
# Getting page info data for: Brookfield, Wisconsin
# Getting page info data for: Buffalo City, Wisconsin
# Getting page info data for: Burlington, Wisconsin
# Getting page info data for: Cedarburg, Wisconsin
# Getting page info data for: Chetek, Wisconsin
# Getting page info data for: Chilton, Wisconsin
# Getting page info data for: Chippewa Falls, Wisconsin
# Getting page info data for: Clintonville, Wisconsin
# Getting page info data for: Colby, Wisconsin
# Getting page info data for: Columbus, Wisconsin
# Getting page info data for: Cornell, Wisconsin
# Getting page info data for: Crandon, Wisconsin
# Getting page info data for: Cuba City, Wisconsin
# Getting page info data for: Cudahy, Wisconsin
# Getting page info data for: Cumberland, Wisconsin
# Getting page info data for: Darlington, Wisconsin
# Getting page info data for: Delafield, Wisconsin
# Getting page info data for: Delavan, Wisconsin
# Getting page info data for: De Pere, Wisconsin
# Getting page info data for: Dodgeville, Wisconsin
# Getting page info data for: Durand, Wisconsin
# Getting page info data for: Eagle River, Wisconsin
# Getting page info data for: Eau Claire, Wisconsin
# Getting page info data for: Edgerton, Wisconsin
# Getting page info data for: Elkhorn, Wisconsin
# Getting page info data for: Elroy, Wisconsin
# Getting page info data for: Evansville, Wisconsin
# Getting page info data for: Fennimore, Wisconsin
# Getting page info data for: Fitchburg, Wisconsin
# Getting page info data for: Fond du Lac, Wisconsin
# Getting page info data for: Fort Atkinson, Wisconsin
# Getting page info data for: Fountain City, Wisconsin
# Getting page info data for: Fox Lake, Wisconsin
# Getting page info data for: Franklin, Milwaukee County, Wisconsin
# Getting page info data for: Galesville, Wisconsin
# Getting page info data for: Gillett, Wisconsin
# Getting page info data for: Glendale, Wisconsin
# Getting page info data for: Glenwood City, Wisconsin
# Getting page info data for: Green Bay, Wisconsin
# Getting page info data for: Green Lake, Wisconsin
# Getting page info data for: Greenfield, Wisconsin
# Getting page info data for: Greenwood, Wisconsin
# Getting page info data for: Hartford, Wisconsin
# Getting page info data for: Hayward, Wisconsin
# Getting page info data for: Hillsboro, Wisconsin
# Getting page info data for: Horicon, Wisconsin
# Getting page info data for: Hudson, Wisconsin
# Getting page info data for: Hurley, Wisconsin
# Getting page info data for: Independence, Wisconsin
# Getting page info data for: Janesville, Wisconsin
# Getting page info data for: Jefferson, Wisconsin
# Getting page info data for: Juneau, Wisconsin
# Getting page info data for: Kaukauna, Wisconsin
# Getting page info data for: Kenosha, Wisconsin
# Getting page info data for: Kewaunee, Wisconsin
# Getting page info data for: Kiel, Wisconsin
# Getting page info data for: La Crosse, Wisconsin
# Getting page info data for: Ladysmith, Wisconsin
# Getting page info data for: Lake Geneva, Wisconsin
# Getting page info data for: Lake Mills, Wisconsin
# Getting page info data for: Lancaster, Wisconsin
# Getting page info data for: Lodi, Wisconsin
# Getting page info data for: Loyal, Wisconsin
# Getting page info data for: Madison, Wisconsin
# Getting page info data for: Manawa, Wisconsin
# Getting page info data for: Manitowoc, Wisconsin
# Getting page info data for: Marinette, Wisconsin
# Getting page info data for: Marion, Wisconsin
# Getting page info data for: Markesan, Wisconsin
# Getting page info data for: Marshfield, Wisconsin
# Getting page info data for: Mauston, Wisconsin
# Getting page info data for: Mayville, Wisconsin
# Getting page info data for: Medford, Wisconsin
# Getting page info data for: Mellen, Wisconsin
# Getting page info data for: Menasha, Wisconsin
# Getting page info data for: Menomonie, Wisconsin
# Getting page info data for: Mequon, Wisconsin
# Getting page info data for: Merrill, Wisconsin
# Getting page info data for: Middleton, Wisconsin
# Getting page info data for: Milton, Wisconsin
# Getting page info data for: Milwaukee
# Getting page info data for: Mineral Point, Wisconsin
# Getting page info data for: Mondovi, Wisconsin
# Getting page info data for: Monona, Wisconsin
# Getting page info data for: Monroe, Wisconsin
# Getting page info data for: Montello, Wisconsin
# Getting page info data for: Montreal, Wisconsin
# Getting page info data for: Mosinee, Wisconsin
# Getting page info data for: Muskego, Wisconsin
# Getting page info data for: Neenah, Wisconsin
# Getting page info data for: Neillsville, Wisconsin
# Getting page info data for: Nekoosa, Wisconsin
# Getting page info data for: New Berlin, Wisconsin
# Getting page info data for: New Holstein, Wisconsin
# Getting page info data for: New Lisbon, Wisconsin
# Getting page info data for: New London, Wisconsin
# Getting page info data for: New Richmond, Wisconsin
# Getting page info data for: Niagara, Wisconsin
# Getting page info data for: Oak Creek, Wisconsin
# Getting page info data for: Oconomowoc, Wisconsin
# Getting page info data for: Oconto, Wisconsin
# Getting page info data for: Oconto Falls, Wisconsin
# Getting page info data for: Omro, Wisconsin
# Getting page info data for: Onalaska, Wisconsin
# Getting page info data for: Oshkosh, Wisconsin
# Getting page info data for: Osseo, Wisconsin
# Getting page info data for: Owen, Wisconsin
# Getting page info data for: Park Falls, Wisconsin
# Getting page info data for: Peshtigo, Wisconsin
# Getting page info data for: Pewaukee, Wisconsin
# Getting page info data for: Phillips, Wisconsin
# Getting page info data for: Pittsville, Wisconsin
# Getting page info data for: Platteville, Wisconsin
# Getting page info data for: Plymouth, Wisconsin
# Getting page info data for: Port Washington, Wisconsin
# Getting page info data for: Portage, Wisconsin
# Getting page info data for: Prairie du Chien, Wisconsin
# Getting page info data for: Prescott, Wisconsin
# Getting page info data for: Princeton, Wisconsin
# Getting page info data for: Racine, Wisconsin
# Getting page info data for: Reedsburg, Wisconsin
# Getting page info data for: Rhinelander, Wisconsin
# Getting page info data for: Rice Lake, Wisconsin
# Getting page info data for: Richland Center, Wisconsin
# Getting page info data for: Ripon, Wisconsin
# Getting page info data for: River Falls, Wisconsin
# Getting page info data for: St. Croix Falls, Wisconsin
# Getting page info data for: St. Francis, Wisconsin
# Getting page info data for: Schofield, Wisconsin
# Getting page info data for: Seymour, Wisconsin
# Getting page info data for: Shawano, Wisconsin
# Getting page info data for: Sheboygan, Wisconsin
# Getting page info data for: Sheboygan Falls, Wisconsin
# Getting page info data for: Shell Lake, Wisconsin
# Getting page info data for: Shullsburg, Wisconsin
# Getting page info data for: South Milwaukee, Wisconsin
# Getting page info data for: Sparta, Wisconsin
# Getting page info data for: Spooner, Wisconsin
# Getting page info data for: Stanley, Wisconsin
# Getting page info data for: Stevens Point, Wisconsin
# Getting page info data for: Stoughton, Wisconsin
# Getting page info data for: Sturgeon Bay, Wisconsin
# Getting page info data for: Sun Prairie, Wisconsin
# Getting page info data for: Superior, Wisconsin
# Getting page info data for: Thorp, Wisconsin
# Getting page info data for: Tomah, Wisconsin
# Getting page info data for: Tomahawk, Wisconsin
# Getting page info data for: Two Rivers, Wisconsin
# Getting page info data for: Verona, Wisconsin
# Getting page info data for: Viroqua, Wisconsin
# Getting page info data for: Washburn, Wisconsin
# Getting page info data for: Waterloo, Wisconsin
# Getting page info data for: Watertown, Wisconsin
# Getting page info data for: Waukesha, Wisconsin
# Getting page info data for: Waupaca, Wisconsin
# Getting page info data for: Waupun, Wisconsin
# Getting page info data for: Wausau, Wisconsin
# Getting page info data for: Wautoma, Wisconsin
# Getting page info data for: Wauwatosa, Wisconsin
# Getting page info data for: West Allis, Wisconsin
# Getting page info data for: West Bend, Wisconsin
# Getting page info data for: West Salem, Wisconsin
# Getting page info data for: Westby, Wisconsin
# Getting page info data for: Weyauwega, Wisconsin
# Getting page info data for: Whitehall, Wisconsin
# Getting page info data for: Whitewater, Wisconsin
# Getting page info data for: Wisconsin Dells, Wisconsin
# Getting page info data for: Wisconsin Rapids, Wisconsin
# Getting page info data for: County (United States)
# Getting page info data for: Afton, Wyoming
# Getting page info data for: Albin, Wyoming
# Getting page info data for: Alpine, Wyoming
# Getting page info data for: Baggs, Wyoming
# Getting page info data for: Bairoil, Wyoming
# Getting page info data for: Bar Nunn, Wyoming
# Getting page info data for: Basin, Wyoming
# Getting page info data for: Bear River, Wyoming
# Getting page info data for: Big Piney, Wyoming
# Getting page info data for: Buffalo, Wyoming
# Getting page info data for: Burlington, Wyoming
# Getting page info data for: Burns, Wyoming
# Getting page info data for: Byron, Wyoming
# Getting page info data for: Casper, Wyoming
# Getting page info data for: Cheyenne, Wyoming
# Getting page info data for: Chugwater, Wyoming
# Getting page info data for: Clearmont, Wyoming
# Getting page info data for: Cody, Wyoming
# Getting page info data for: Cokeville, Wyoming
# Getting page info data for: Cowley, Wyoming
# Getting page info data for: Dayton, Wyoming
# Getting page info data for: Deaver, Wyoming
# Getting page info data for: Diamondville, Wyoming
# Getting page info data for: Dixon, Wyoming
# Getting page info data for: Douglas, Wyoming
# Getting page info data for: Dubois, Wyoming
# Getting page info data for: East Thermopolis, Wyoming
# Getting page info data for: Edgerton, Wyoming
# Getting page info data for: Elk Mountain, Wyoming
# Getting page info data for: Encampment, Wyoming
# Getting page info data for: Evanston, Wyoming
# Getting page info data for: Evansville, Wyoming
# Getting page info data for: Fort Laramie, Wyoming
# Getting page info data for: Frannie, Wyoming
# Getting page info data for: Gillette, Wyoming
# Getting page info data for: Glendo, Wyoming
# Getting page info data for: Glenrock, Wyoming
# Getting page info data for: Granger, Wyoming
# Getting page info data for: Green River, Wyoming
# Getting page info data for: Greybull, Wyoming
# Getting page info data for: Guernsey, Wyoming
# Getting page info data for: Hanna, Wyoming
# Getting page info data for: Hartville, Wyoming
# Getting page info data for: Hudson, Wyoming
# Getting page info data for: Hulett, Wyoming
# Getting page info data for: Jackson, Wyoming
# Getting page info data for: Kaycee, Wyoming
# Getting page info data for: Kemmerer, Wyoming
# Getting page info data for: Kirby, Wyoming
# Getting page info data for: La Barge, Wyoming
# Getting page info data for: La Grange, Wyoming
# Getting page info data for: Lander, Wyoming
# Getting page info data for: Laramie, Wyoming
# Getting page info data for: Lingle, Wyoming
# Getting page info data for: Lost Springs, Wyoming
# Getting page info data for: Lovell, Wyoming
# Getting page info data for: Lusk, Wyoming
# Getting page info data for: Lyman, Wyoming
# Getting page info data for: Manderson, Wyoming
# Getting page info data for: Manville, Wyoming
# Getting page info data for: Marbleton, Wyoming
# Getting page info data for: Medicine Bow, Wyoming
# Getting page info data for: Meeteetse, Wyoming
# Getting page info data for: Midwest, Wyoming
# Getting page info data for: Mills, Wyoming
# Getting page info data for: Moorcroft, Wyoming
# Getting page info data for: Mountain View, Wyoming
# Getting page info data for: Newcastle, Wyoming
# Getting page info data for: Opal, Wyoming
# Getting page info data for: Pavillion, Wyoming
# Getting page info data for: Pine Bluffs, Wyoming
# Getting page info data for: Pinedale, Wyoming
# Getting page info data for: Pine Haven, Wyoming
# Getting page info data for: Powell, Wyoming
# Getting page info data for: Ranchester, Wyoming
# Getting page info data for: Rawlins, Wyoming
# Getting page info data for: Riverside, Wyoming
# Getting page info data for: Riverton, Wyoming
# Getting page info data for: Rock River, Wyoming
# Getting page info data for: Rock Springs, Wyoming
# Getting page info data for: Rolling Hills, Wyoming
# Getting page info data for: Saratoga, Wyoming
# Getting page info data for: Sheridan, Wyoming
# Getting page info data for: Shoshoni, Wyoming
# Getting page info data for: Sinclair, Wyoming
# Getting page info data for: Star Valley Ranch, Wyoming
# Getting page info data for: Sundance, Wyoming
# Getting page info data for: Superior, Wyoming
# Getting page info data for: Ten Sleep, Wyoming
# Getting page info data for: Thayne, Wyoming
# Getting page info data for: Thermopolis, Wyoming
# Getting page info data for: Torrington, Wyoming
# Getting page info data for: Upton, Wyoming
# Getting page info data for: Van Tassell, Wyoming
# Getting page info data for: Wamsutter, Wyoming
# Getting page info data for: Wheatland, Wyoming
# Getting page info data for: Worland, Wyoming
# Getting page info data for: Wright, Wyoming
# Getting page info data for: Yoder, Wyoming

# %% [markdown]
# #### Step 1B: Getting Population data for these cities

# %%
population_df=pd.read_excel('/Users/sayo/Documents/Projects/Home-Projects/ScratchPad/NST-EST2022-POP.xlsx'
                            ,header=[3]
                            ,names=['Geography'
                                    ,'Pop_estimate_april2020'
                                    ,'Pop_estimate_july2020'
                                    ,'Pop_estimate_july2021'
                                    ,'Pop_estimate_july2022']
                            ,skiprows=5
                            )
population_df['State']=population_df['Geography'].str.replace(".","",regex=False)
population_df.drop(columns=['Geography'],inplace=True)
population_df.head(10)
# Out:
#    Pop_estimate_april2020  Pop_estimate_july2020  Pop_estimate_july2021  \
# 0               5024356.0              5031362.0              5049846.0
# 1                733378.0               732923.0               734182.0
# 2               7151507.0              7179943.0              7264877.0
# 3               3011555.0              3014195.0              3028122.0
# 4              39538245.0             39501653.0             39142991.0
# 5               5773733.0              5784865.0              5811297.0
# 6               3605942.0              3597362.0              3623355.0
# 7                989957.0               992114.0              1004807.0
# 8                689546.0               670868.0               668791.0
# 9              21538226.0             21589602.0             21828069.0
#
#    Pop_estimate_july2022                 State
# 0              5074296.0               Alabama
# 1               733583.0                Alaska
# 2              7359197.0               Arizona
# 3              3045637.0              Arkansas
# 4             39029342.0            California
# 5              5839926.0              Colorado
# 6              3626205.0           Connecticut
# 7              1018396.0              Delaware
# 8               671803.0  District of Columbia
# 9             22244823.0               Florida

# %% [markdown]
# #### Step 1C: Getting Region data

# %%
csv_file_path='/Users/sayo/Documents/Projects/Home-Projects/ScratchPad/US States by Region - US Census Bureau.xlsx'

# %%
# Read the Excel file
df = pd.read_excel(csv_file_path, header=0)

# Remove empty rows
df = df.dropna(how='all')
# Create a nested dictionary from the DataFrame
data = {}
current_region = None
current_division = None
for index, col in df.iterrows():
    if pd.notnull(col[0]):
        current_region = col[0]
        data[current_region] = {}
    elif pd.notnull(col[1]):
        current_division = col[1]
        data[current_region][current_division] = []
    elif pd.notnull(col[2]):
        state= col[2]
        data[current_region][current_division].append(state)

# Convert the nested dictionary to JSON
json_data = json.dumps(data, indent=4)

# Write the JSON data to a file
if os.path.exists('staging_outputs/region_df.json'):
    os.remove('staging_outputs/region_df.json')
with open('region_df.json', 'a') as json_file:
    json_file.write(json_data)

os.replace('/Users/sayo/Documents/Projects/Home-Projects/Human-Centered-Data-Science/data-512-homework_2/notebooks/region_df.json',
           '/Users/sayo/Documents/Projects/Home-Projects/Human-Centered-Data-Science/data-512-homework_2/staging_outputs/region_df.json')

print("JSON data has been written to region_df.json in staging_ouput")
# Out:
# JSON data has been written to region_df.json in staging_ouput

# %% [markdown]
# #### Step 1D: Converting JSON into Dataframe for ease of merging

# %% [markdown]
# #### First we need to convert the city info JSON output to Dataframe for ease of merging.

# %%
## convert city info json to pandas DF
with open('wikipedia_us_city_info.json', "r") as read_content: 
    data_json=json.load(read_content)

#print(data_json.items())
data_list=[]
for city, city_data in data_json.items():
    for pageid, page_data in city_data.items():
        flat_data = {
            #"State":city.split(',',2)[1],
            #"City": city.split(',',2)[0],
            "City": city,
            "PageID": pageid,
            "Title": page_data["title"],
            "LatestRevisionid":page_data["lastrevid"]
        }
        data_list.append(flat_data)

city_wiki_df = pd.DataFrame(data_list)
print(len(city_wiki_df))
print(city_wiki_df.head(-10))
# Out:
# 21519
#                              City  PageID                       Title  \
# 0              Abbeville, Alabama  104730          Abbeville, Alabama
# 1             Adamsville, Alabama  104761         Adamsville, Alabama
# 2                Addison, Alabama  105188            Addison, Alabama
# 3                  Akron, Alabama  104726              Akron, Alabama
# 4              Alabaster, Alabama  105109          Alabaster, Alabama
# ...                           ...     ...                         ...
# 21504           Sinclair, Wyoming  140079           Sinclair, Wyoming
# 21505  Star Valley Ranch, Wyoming  140145  Star Valley Ranch, Wyoming
# 21506           Sundance, Wyoming  140089           Sundance, Wyoming
# 21507           Superior, Wyoming  140218           Superior, Wyoming
# 21508          Ten Sleep, Wyoming  140241          Ten Sleep, Wyoming
#
#        LatestRevisionid
# 0            1171163550
# 1            1177621427
# 2            1168359898
# 3            1165909508
# 4            1179139816
# ...                 ...
# 21504        1162125136
# 21505        1166752249
# 21506        1166330861
# 21507        1166330907
# 21508        1173313467
#
# [21509 rows x 4 columns]

# %% [markdown]
# While loading the city data from Wikipedia, I noticed few invalid city names. All valid city names are of the format : City, State. I will use a regex to identify rows which fall into that format and ones which are of invalid format.

# %%
# Regular expression pattern for valid 'city, State' format
#valid_pattern1 = r'^[A-Za-z\s\.\'()\'-]+,\s[A-Za-z\s]+$'
#valid_pattern2 = r'^[A-Za-z\s\.\'()\'-]+,\s[A-Za-z\s]+,\s[A-Za-z\s]+$'

# %%
# Invalid rows
#invalid_rows = city_wiki_df[~city_wiki_df['Title'].str.contains(valid_pattern1, na=False)
#                            & ~city_wiki_df['Title'].str.contains(valid_pattern2, na=False)]
#print(invalid_rows)

# %% [markdown]
# ### Step 2: Requesting ORES scores through LiftWing ML Service API

# %%
#########
#
#    CONSTANTS
#

#    The current LiftWing ORES API endpoint and prediction model
#
API_ORES_LIFTWING_ENDPOINT = "https://api.wikimedia.org/service/lw/inference/v1/models/{model_name}:predict"
API_ORES_EN_QUALITY_MODEL = "enwiki-articlequality"

#
#    The throttling rate is a function of the Access token that you are granted when you request the token. The constants
#    come from dissecting the token and getting the rate limits from the granted token. An example of that is below.
#
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (60.0/5000.0)-API_LATENCY_ASSUMED

#    When making automated requests we should include something that is unique to the person making the request
#    This should include an email - your UW email would be good to put in there
#    
#    Because all LiftWing API requests require some form of authentication, you need to provide your access token
#    as part of the header too
#
REQUEST_HEADER_TEMPLATE = {
    'User-Agent': "<{email_address}>, University of Washington, MSDS DATA 512 - AUTUMN 2023",
    'Content-Type': 'application/json',
    'Authorization': "Bearer {access_token}"
}
#
#    This is a template for the parameters that we need to supply in the headers of an API request
#
REQUEST_HEADER_PARAMS_TEMPLATE = {
    'email_address' : "",         # your email address should go here
    'access_token'  : ""          # the access token you create will need to go here
}

#
#    A dictionary of English Wikipedia article titles (keys) and sample revision IDs that can be used for this ORES scoring example
#
#ARTICLE_REVISIONS = { 'Bison':1085687913 , 'Northern flicker':1086582504 , 'Red squirrel':1083787665 , 'Chinook salmon':1085406228 , 'Horseshoe bat':1060601936 }

#
#    This is a template of the data required as a payload when making a scoring request of the ORES model
#
ORES_REQUEST_DATA_TEMPLATE = {
    "lang":        "en",     # required that its english - we're scoring English Wikipedia revisions
    "rev_id":      "",       # this request requires a revision id
    "features":    True
}

#
#    These are used later - defined here so they, at least, have empty values
#
USERNAME = ""
ACCESS_TOKEN = ""
#

# %%
#   Once you've done the right set up with your Wikimedia account, it should provide you with three different keys, a Client ID,
#   a Client secret, and a Access token.
#
#   In this case I don't want to distribute my keys with the source of the notebook, so I wrote a key manager object that helps
#   track all of my API keys - a username and domain name retrieves the key. The key manager hides the keys on disk separate
#   from the code. A common code idiom to hide API keys will use code to extract the key from an OS environment variable. 

USERNAME = "" #<redacted>
ACCESS_TOKEN = "" #<redacted>

# %% [markdown]
# #### Define a function to make the ORES API request
#
# The API request will be made using a function to encapsulate call and make access reusable in other notebooks. The procedure is parameterized, relying on the constants above for some important default parameters. The primary assumption is that this function will be used to request data for a set of article revisions. The main parameter is 'article_revid'. One should be able to simply pass in a new article revision id on each call and get back a python dictionary as the result. A valid result will be a dictionary that contains the probabilities that the specific revision is one of six different article quality levels. Generally, quality level with the highest probability score is considered the quality level for the article. This can be tricky when you have two (or more) highly probable quality levels.

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_ores_score_per_article(article_revid = None, email_address=None, access_token=None,
                                   endpoint_url = API_ORES_LIFTWING_ENDPOINT, 
                                   model_name = API_ORES_EN_QUALITY_MODEL, 
                                   request_data = ORES_REQUEST_DATA_TEMPLATE, 
                                   header_format = REQUEST_HEADER_TEMPLATE, 
                                   header_params = REQUEST_HEADER_PARAMS_TEMPLATE):
    
    #    Make sure we have an article revision id, email and token
    #    This approach prioritizes the parameters passed in when making the call
    if article_revid:
        request_data['rev_id'] = article_revid
    if email_address:
        header_params['email_address'] = email_address
    if access_token:
        header_params['access_token'] = access_token
    
    #   Making a request requires a revision id - an email address - and the access token
    if not request_data['rev_id']:
        raise Exception("Must provide an article revision id (rev_id) to score articles")
    if not header_params['email_address']:
        raise Exception("Must provide an 'email_address' value")
    if not header_params['access_token']:
        raise Exception("Must provide an 'access_token' value")
    
    # Create the request URL with the specified model parameter - default is a article quality score request
    request_url = endpoint_url.format(model_name=model_name)
    
    # Create a compliant request header from the template and the supplied parameters
    headers = dict()
    for key in header_format.keys():
        headers[str(key)] = header_format[key].format(**header_params)
    
    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free data
        # source like ORES - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        #response = requests.get(request_url, headers=headers)
        response = requests.post(request_url, headers=headers, data=json.dumps(request_data))
        #response = requests.post(request_url, headers=headers, data=request_data)        
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
#
#  
# What article - the key for the article dictionary defined above

article_title = city_wiki_df['Title'][1]
#
#   We have to pass in some parameters used for the request header. Create a copy of the template and fill in some fields.
hparams = REQUEST_HEADER_PARAMS_TEMPLATE.copy()
hparams['email_address'] = "sboral@uw.edu"
hparams['access_token'] = ACCESS_TOKEN
#
#    We can also do this with the request data - although this might not be as useful as with the header params
rd = ORES_REQUEST_DATA_TEMPLATE.copy()
rd['rev_id']= 1171098806
print(rd)
#
print(f"ORES scores for '{article_title}' with revid: {1171098806}")
#
#    Make the call, just pass in the article revision ID and the header parameters
score = request_ores_score_per_article(article_revid = 1171098806, 
                                       email_address="sboral@uw.edu", 
                                       access_token=ACCESS_TOKEN,
                                       header_params=hparams)

#
#    Output the result
print(score['enwiki']['scores'][str(1171098806)]['articlequality']['score']['prediction'])
#
# Out:
# {'lang': 'en', 'rev_id': 1171098806, 'features': True}
# ORES scores for 'Abbeville, Alabama' with revid: 1171098806
# C

# %%
# This conversion is required to make the JSON data serializable
city_wiki_df['LatestRevisionid'] = city_wiki_df['LatestRevisionid'].astype(np.int64)
# Adding a ORES SCore column and Setting it to a default value
city_wiki_df['ORES_Score']='0'

# %%
ores_scores_df=pd.DataFrame()

# %%
# What article - the key for the article dictionary defined above
for i in range(len(city_wiki_df)):
    article_title = city_wiki_df['Article_Title'][i]
    
#    We can also do this with the request data - although this might not be as useful as with the header params
    rd = ORES_REQUEST_DATA_TEMPLATE.copy()
    rd['rev_id']= city_wiki_df['Revision_ID'][i].tolist()
#   We have to pass in some parameters used for the request header. Create a copy of the template and fill in some fields.
    hparams = REQUEST_HEADER_PARAMS_TEMPLATE.copy()
    hparams['email_address'] = "sboral@uw.edu"
    hparams['access_token'] = ACCESS_TOKEN  
#
    print(f"ORES scores for '{article_title}' with revid: {city_wiki_df['Revision_ID'][i]}")
#
#    Make the call, just pass in the article revision ID and the header parameters
    revid=city_wiki_df['Revision_ID'][i]
    score = request_ores_score_per_article(
                                           request_data=rd,
                                           header_params=hparams)


#    Output the result
    ores_scores_df.loc[i,'Revision_ID']=revid
    ores_scores_df.loc[i,'ORES_score']= [score]
    #city_wiki_df.at[i,'ORES_Score']=score['enwiki']['scores'][str(city_wiki_df['LatestRevisionid'][i])]['articlequality']['score']['prediction']
#
ores_scores_df.to_csv('ores_scores_df2.csv')
# Out:
# ORES scores for 'Abbeville, Alabama' with revid: 1171163550
# ORES scores for 'Adamsville, Alabama' with revid: 1177621427
# ORES scores for 'Addison, Alabama' with revid: 1168359898
# ORES scores for 'Akron, Alabama' with revid: 1165909508
# ORES scores for 'Alabaster, Alabama' with revid: 1179139816
# ORES scores for 'Albertville, Alabama' with revid: 1179198677
# ORES scores for 'Alexander City, Alabama' with revid: 1179140073
# ORES scores for 'Aliceville, Alabama' with revid: 1167792390
# ORES scores for 'Allgood, Alabama' with revid: 1165909718
# ORES scores for 'Altoona, Alabama' with revid: 1165909823
# ORES scores for 'Andalusia, Alabama' with revid: 1179141586
# ORES scores for 'Anderson, Lauderdale County, Alabama' with revid: 662691565
# ORES scores for 'Anniston, Alabama' with revid: 1176049382
# ORES scores for 'Arab, Alabama' with revid: 1171375371
# ORES scores for 'Ardmore, Alabama' with revid: 1176903479
# ORES scores for 'Argo, Alabama' with revid: 1177623964
# ORES scores for 'Ariton, Alabama' with revid: 1166014478
# ORES scores for 'Arley, Alabama' with revid: 1166014498
# ORES scores for 'Ashford, Alabama' with revid: 1166014593
# ORES scores for 'Ashland, Alabama' with revid: 1174331705
# ORES scores for 'Ashville, Alabama' with revid: 1148844011
# ORES scores for 'Athens, Alabama' with revid: 1175308807
# ORES scores for 'Atmore, Alabama' with revid: 1167926420
# ORES scores for 'Attalla, Alabama' with revid: 1165507856
# ORES scores for 'Auburn, Alabama' with revid: 1179878794
# ORES scores for 'Autaugaville, Alabama' with revid: 1166014815
# ORES scores for 'Avon, Alabama' with revid: 1166014861
# ORES scores for 'Babbie, Alabama' with revid: 1168820544
# ORES scores for 'Baileyton, Alabama' with revid: 1166014939
# ORES scores for 'Bakerhill, Alabama' with revid: 1166014954
# ORES scores for 'Banks, Alabama' with revid: 1166014997
# ORES scores for 'Bay Minette, Alabama' with revid: 1177963600
# ORES scores for 'Bayou La Batre, Alabama' with revid: 1177999052
# ORES scores for 'Bear Creek, Alabama' with revid: 1166015184
# ORES scores for 'Beatrice, Alabama' with revid: 1166015214
# ORES scores for 'Beaverton, Alabama' with revid: 1166015251
# ORES scores for 'Belk, Alabama' with revid: 1166015313
# ORES scores for 'Benton, Alabama' with revid: 1166015434
# ORES scores for 'Berlin, Alabama' with revid: 1166015476
# ORES scores for 'Berry, Alabama' with revid: 1166015515
# ORES scores for 'Bessemer, Alabama' with revid: 1178999596
# ORES scores for 'Billingsley, Alabama' with revid: 1166015695
# ORES scores for 'Birmingham, Alabama' with revid: 1179944837
# ORES scores for 'Black, Alabama' with revid: 1166015772
# ORES scores for 'Blountsville, Alabama' with revid: 1105978061
# ORES scores for 'Blue Springs, Alabama' with revid: 1166015902
# ORES scores for 'Boaz, Alabama' with revid: 1177138566
# ORES scores for 'Boligee, Alabama' with revid: 1166015957
# ORES scores for 'Bon Air, Alabama' with revid: 1166015981
# ORES scores for 'Brantley, Alabama' with revid: 1165814013
# ORES scores for 'Brent, Alabama' with revid: 1172245542
# ORES scores for 'Brewton, Alabama' with revid: 1162427481
# ORES scores for 'Bridgeport, Alabama' with revid: 1165537046
# ORES scores for 'Brighton, Alabama' with revid: 1177621572
# ORES scores for 'Brilliant, Alabama' with revid: 1166016323
# ORES scores for 'Brookside, Alabama' with revid: 1170769013
# ORES scores for 'Brookwood, Alabama' with revid: 1178216914
# ORES scores for 'Brundidge, Alabama' with revid: 1165537457
# ORES scores for 'Butler, Alabama' with revid: 1144752979
# ORES scores for 'Calera, Alabama' with revid: 1165537934
# ORES scores for 'Camden, Alabama' with revid: 1176316224
# ORES scores for 'Camp Hill, Alabama' with revid: 1166017104
# ORES scores for 'Carbon Hill, Alabama' with revid: 1175376595
# ORES scores for 'Cardiff, Alabama' with revid: 1166017260
# ORES scores for 'Carolina, Alabama' with revid: 1166017310
# ORES scores for 'Carrollton, Alabama' with revid: 1096812581
# ORES scores for 'Castleberry, Alabama' with revid: 1166017442
# ORES scores for 'Cedar Bluff, Alabama' with revid: 1177836881
# ORES scores for 'Center Point, Alabama' with revid: 1174837569
# ORES scores for 'Centre, Alabama' with revid: 1164314017
# ORES scores for 'Centreville, Alabama' with revid: 1172134285
# ORES scores for 'Chatom, Alabama' with revid: 1159488446
# ORES scores for 'Chelsea, Alabama' with revid: 1165539092
# ORES scores for 'Cherokee, Alabama' with revid: 1166017755
# ORES scores for 'Chickasaw, Alabama' with revid: 1165539195
# ORES scores for 'Childersburg, Alabama' with revid: 1165539227
# ORES scores for 'Citronelle, Alabama' with revid: 1165539457
# ORES scores for 'Clanton, Alabama' with revid: 1158612343
# ORES scores for 'Clay, Alabama' with revid: 1177621993
# ORES scores for 'Clayhatchee, Alabama' with revid: 1166018079
# ORES scores for 'Clayton, Alabama' with revid: 1155236230
# ORES scores for 'Cleveland, Alabama' with revid: 1168466910
# ORES scores for 'Clio, Alabama' with revid: 1165644511
# ORES scores for 'Coaling, Alabama' with revid: 1166018304
# ORES scores for 'Coffee Springs, Alabama' with revid: 1166018326
# ORES scores for 'Coffeeville, Alabama' with revid: 1166029689
# ORES scores for 'Coker, Alabama' with revid: 1166018360
# ORES scores for 'Collinsville, Alabama' with revid: 1177947751
# ORES scores for 'Colony, Alabama' with revid: 1166018463
# ORES scores for 'Columbia, Alabama' with revid: 1166018475
# ORES scores for 'Columbiana, Alabama' with revid: 1151357569
# ORES scores for 'Coosada, Alabama' with revid: 1172561590
# ORES scores for 'Cordova, Alabama' with revid: 1165645181
# ORES scores for 'Cottonwood, Alabama' with revid: 1096812941
# ORES scores for 'County Line, Alabama' with revid: 1166018950
# ORES scores for 'Courtland, Alabama' with revid: 1157580326
# ORES scores for 'Cowarts, Alabama' with revid: 1166019003
# ORES scores for 'Creola, Alabama' with revid: 1139764613
# ORES scores for 'Crossville, Alabama' with revid: 1166066155
# ORES scores for 'Cuba, Alabama' with revid: 1175879685
# ORES scores for 'Cullman, Alabama' with revid: 1180017307
# ORES scores for 'Cusseta, Alabama' with revid: 1172824345
# ORES scores for 'Dadeville, Alabama' with revid: 1158607851
# ORES scores for 'Daleville, Alabama' with revid: 1154496305
# ORES scores for 'Daphne, Alabama' with revid: 1165646156
# ORES scores for 'Dauphin Island, Alabama' with revid: 1174226588
# ORES scores for 'Daviston, Alabama' with revid: 1166066473
# ORES scores for 'Dayton, Alabama' with revid: 1166066487
# ORES scores for 'Deatsville, Alabama' with revid: 1166066515
# ORES scores for 'Decatur, Alabama' with revid: 1178063438
# ORES scores for 'Demopolis, Alabama' with revid: 1161394946
# ORES scores for 'Detroit, Alabama' with revid: 1166066756
# ORES scores for 'Dodge City, Alabama' with revid: 1166066982
# ORES scores for 'Dora, Alabama' with revid: 1165647022
# ORES scores for 'Dothan, Alabama' with revid: 1179231968
# ORES scores for 'Double Springs, Alabama' with revid: 1159024876
# ORES scores for 'Douglas, Alabama' with revid: 1166067023
# ORES scores for 'Dozier, Alabama' with revid: 1096813187
# ORES scores for 'Dutton, Alabama' with revid: 1166067175
# ORES scores for 'East Brewton, Alabama' with revid: 1165647609
# ORES scores for 'Eclectic, Alabama' with revid: 1145048302
# ORES scores for 'Edwardsville, Alabama' with revid: 1166067508
# ORES scores for 'Elba, Alabama' with revid: 1163400900
# ORES scores for 'Elberta, Alabama' with revid: 1175895043
# ORES scores for 'Eldridge, Alabama' with revid: 1178177223
# ORES scores for 'Elkmont, Alabama' with revid: 1176555126
# ORES scores for 'Elmore, Alabama' with revid: 1166067658
# ORES scores for 'Emelle, Alabama' with revid: 1158753175
# ORES scores for 'Enterprise, Alabama' with revid: 1160273773
# ORES scores for 'Epes, Alabama' with revid: 1166067751
# ORES scores for 'Ethelsville, Alabama' with revid: 1166067848
# ORES scores for 'Eufaula, Alabama' with revid: 1160493671
# ORES scores for 'Eutaw, Alabama' with revid: 1158611853
# ORES scores for 'Eva, Alabama' with revid: 1166067877
# ORES scores for 'Evergreen, Conecuh County, Alabama' with revid: 1158611789
# ORES scores for 'Excel, Alabama' with revid: 1166067942
# ORES scores for 'Fairfield, Alabama' with revid: 1177239572
# ORES scores for 'Fairhope, Alabama' with revid: 1173963070
# ORES scores for 'Fairview, Alabama' with revid: 1166068021
# ORES scores for 'Falkville, Alabama' with revid: 1166068054
# ORES scores for 'Faunsdale, Alabama' with revid: 1167428050
# ORES scores for 'Fayette, Alabama' with revid: 1142947111
# ORES scores for 'Five Points, Alabama' with revid: 1166068289
# ORES scores for 'Flomaton, Alabama' with revid: 1166244039
# ORES scores for 'Florala, Alabama' with revid: 1166068321
# ORES scores for 'Florence, Alabama' with revid: 1178304592
# ORES scores for 'Foley, Alabama' with revid: 1166414056
# ORES scores for 'Forkland, Alabama' with revid: 1166068466
# ORES scores for 'Fort Deposit, Alabama' with revid: 1177020476
# ORES scores for 'Fort Payne, Alabama' with revid: 1172551841
# ORES scores for 'Franklin, Alabama' with revid: 1166068620
# ORES scores for 'Frisco City, Alabama' with revid: 1166068863
# ORES scores for 'Fruithurst, Alabama' with revid: 1166068877
# ORES scores for 'Fulton, Alabama' with revid: 1166068885
# ORES scores for 'Fultondale, Alabama' with revid: 1165840932
# ORES scores for 'Fyffe, Alabama' with revid: 1160192215
# ORES scores for 'Gadsden, Alabama' with revid: 1177146243
# ORES scores for 'Gainesville, Alabama' with revid: 1166068936
# ORES scores for 'Gantt, Alabama' with revid: 1180408898
# ORES scores for 'Garden City, Alabama' with revid: 1166068968
# ORES scores for 'Gardendale, Alabama' with revid: 1175530987
# ORES scores for 'Gaylesville, Alabama' with revid: 1166069113
# ORES scores for 'Geiger, Alabama' with revid: 1166069121
# ORES scores for 'Geneva, Alabama' with revid: 1179698088
# ORES scores for 'Georgiana, Alabama' with revid: 1178540000
# ORES scores for 'Geraldine, Alabama' with revid: 1166069211
# ORES scores for 'Gilbertown, Alabama' with revid: 1166069407
# ORES scores for 'Glen Allen, Alabama' with revid: 1166069457
# ORES scores for 'Glencoe, Alabama' with revid: 1165748058
# ORES scores for 'Glenwood, Alabama' with revid: 1096814086
# ORES scores for 'Goldville, Alabama' with revid: 1177535939
# ORES scores for 'Good Hope, Alabama' with revid: 1165748200
# ORES scores for 'Goodwater, Alabama' with revid: 1166069571
# ORES scores for 'Gordo, Alabama' with revid: 1176908359
# ORES scores for 'Gordon, Alabama' with revid: 1166069580
# ORES scores for 'Gordonville, Alabama' with revid: 1166069594
# ORES scores for 'Goshen, Alabama' with revid: 1166069601
# ORES scores for 'Grant, Alabama' with revid: 1166069728
# ORES scores for 'Graysville, Alabama' with revid: 1177622200
# ORES scores for 'Greensboro, Alabama' with revid: 1172134373
# ORES scores for 'Greenville, Alabama' with revid: 1171417115
# ORES scores for 'Grimes, Alabama' with revid: 1166180119
# ORES scores for 'Grove Hill, Alabama' with revid: 1144754911
# ORES scores for 'Guin, Alabama' with revid: 1173001379
# ORES scores for 'Gulf Shores, Alabama' with revid: 1174473447
# ORES scores for 'Guntersville, Alabama' with revid: 1169878221
# ORES scores for 'Gurley, Alabama' with revid: 1173078483
# ORES scores for 'Gu-Win, Alabama' with revid: 1175521277
# ORES scores for 'Hackleburg, Alabama' with revid: 1167581471
# ORES scores for 'Haleburg, Alabama' with revid: 1166180281
# ORES scores for 'Haleyville, Alabama' with revid: 1168590141
# ORES scores for 'Hamilton, Alabama' with revid: 1170634832
# ORES scores for 'Hammondville, Alabama' with revid: 1166180369
# ORES scores for 'Hanceville, Alabama' with revid: 1169612470
# ORES scores for 'Harpersville, Alabama' with revid: 1177953234
# ORES scores for 'Hartford, Alabama' with revid: 1165749307
# ORES scores for 'Hartselle, Alabama' with revid: 1165749341
# ORES scores for 'Hayden, Alabama' with revid: 1166180747
# ORES scores for 'Hayneville, Alabama' with revid: 1166180764
# ORES scores for 'Headland, Alabama' with revid: 1168369252
# ORES scores for 'Heath, Alabama' with revid: 1166180800
# ORES scores for 'Heflin, Alabama' with revid: 1176321971
# ORES scores for 'Helena, Alabama' with revid: 1177702091
# ORES scores for 'Henagar, Alabama' with revid: 1165749718
# ORES scores for 'Highland Lake, Alabama' with revid: 1166180993
# ORES scores for 'Hillsboro, Alabama' with revid: 1166181055
# ORES scores for 'Hobson City, Alabama' with revid: 1166181157
# ORES scores for 'Hodges, Alabama' with revid: 1166181162
# ORES scores for 'Hokes Bluff, Alabama' with revid: 1165750177
# ORES scores for 'Holly Pond, Alabama' with revid: 1166181271
# ORES scores for 'Hollywood, Alabama' with revid: 1166181286
# ORES scores for 'Homewood, Alabama' with revid: 1177622299
# ORES scores for 'Hoover, Alabama' with revid: 1180348406
# ORES scores for 'Horn Hill, Alabama' with revid: 1166181398
# ORES scores for 'Hueytown, Alabama' with revid: 1177622536
# ORES scores for 'Huntsville, Alabama' with revid: 1180130440
# ORES scores for 'Hurtsboro, Alabama' with revid: 1096814754
# ORES scores for 'Hytop, Alabama' with revid: 1166181602
# ORES scores for 'Ider, Alabama' with revid: 1166181612
# ORES scores for 'Indian Springs Village, Alabama' with revid: 1166181665
# ORES scores for 'Irondale, Alabama' with revid: 1169440818
# ORES scores for 'Jackson, Alabama' with revid: 1165750992
# ORES scores for 'Jackson's Gap, Alabama' with revid: 1166181798
# ORES scores for 'Jacksonville, Alabama' with revid: 1175988040
# ORES scores for 'Jasper, Alabama' with revid: 1174380579
# ORES scores for 'Jemison, Alabama' with revid: 1165751151
# ORES scores for 'Kansas, Alabama' with revid: 1166182143
# ORES scores for 'Kellyton, Alabama' with revid: 1166182186
# ORES scores for 'Kennedy, Alabama' with revid: 1166182247
# ORES scores for 'Killen, Alabama' with revid: 1166182386
# ORES scores for 'Kimberly, Alabama' with revid: 1177622633
# ORES scores for 'Kinsey, Alabama' with revid: 1166182487
# ORES scores for 'Kinston, Alabama' with revid: 1166182489
# ORES scores for 'LaFayette, Alabama' with revid: 1165752571
# ORES scores for 'Lake View, Alabama' with revid: 1170831381
# ORES scores for 'Lakeview, Alabama' with revid: 1166205391
# ORES scores for 'Lanett, Alabama' with revid: 1165889187
# ORES scores for 'Langston, Alabama' with revid: 1171521067
# ORES scores for 'Leeds, Alabama' with revid: 1179531175
# ORES scores for 'Leesburg, Alabama' with revid: 1166205728
# ORES scores for 'Leighton, Alabama' with revid: 1148926606
# ORES scores for 'Lester, Alabama' with revid: 1166205815
# ORES scores for 'Level Plains, Alabama' with revid: 1165890044
# ORES scores for 'Lexington, Alabama' with revid: 1166205880
# ORES scores for 'Libertyville, Alabama' with revid: 1166205930
# ORES scores for 'Lincoln, Alabama' with revid: 1165890317
# ORES scores for 'Linden, Alabama' with revid: 1170891816
# ORES scores for 'Lineville, Alabama' with revid: 1165890459
# ORES scores for 'Lipscomb, Alabama' with revid: 1177622747
# ORES scores for 'Lisman, Alabama' with revid: 1166206088
# ORES scores for 'Littleville, Alabama' with revid: 1166206172
# ORES scores for 'Livingston, Alabama' with revid: 1165891122
# ORES scores for 'Loachapoka, Alabama' with revid: 1166206211
# ORES scores for 'Lockhart, Alabama' with revid: 1166206220
# ORES scores for 'Locust Fork, Alabama' with revid: 1173287337
# ORES scores for 'Louisville, Alabama' with revid: 1166206343
# ORES scores for 'Lowndesboro, Alabama' with revid: 1166206408
# ORES scores for 'Loxley, Alabama' with revid: 1170361974
# ORES scores for 'Luverne, Alabama' with revid: 1173068585
# ORES scores for 'Lynn, Alabama' with revid: 1166206561
# ORES scores for 'Madison, Alabama' with revid: 1177703025
# ORES scores for 'Madrid, Alabama' with revid: 1166206649
# ORES scores for 'Magnolia Springs, Alabama' with revid: 1166206656
# ORES scores for 'Malvern, Alabama' with revid: 1166206718
# ORES scores for 'Maplesville, Alabama' with revid: 1166206829
# ORES scores for 'Margaret, Alabama' with revid: 1165892174
# ORES scores for 'Marion, Alabama' with revid: 1165892206
# ORES scores for 'Maytown, Alabama' with revid: 1166207284
# ORES scores for 'McIntosh, Alabama' with revid: 1176350576
# ORES scores for 'McKenzie, Alabama' with revid: 1166207344
# ORES scores for 'McMullen, Alabama' with revid: 1166207363
# ORES scores for 'Memphis, Alabama' with revid: 1166207484
# ORES scores for 'Mentone, Alabama' with revid: 1166207510
# ORES scores for 'Midfield, Alabama' with revid: 1165893352
# ORES scores for 'Midland City, Alabama' with revid: 1166207749
# ORES scores for 'Midway, Alabama' with revid: 1158753496
# ORES scores for 'Millbrook, Alabama' with revid: 1178021676
# ORES scores for 'Millport, Alabama' with revid: 1166207935
# ORES scores for 'Millry, Alabama' with revid: 1166207936
# ORES scores for 'Mobile, Alabama' with revid: 1180350145
# ORES scores for 'Monroeville, Alabama' with revid: 1172371452
# ORES scores for 'Montevallo, Alabama' with revid: 1177552745
# ORES scores for 'Montgomery, Alabama' with revid: 1180299743
# ORES scores for 'Moody, Alabama' with revid: 1179508395
# ORES scores for 'Mooresville, Alabama' with revid: 1169255573
# ORES scores for 'Morris, Alabama' with revid: 1177624137
# ORES scores for 'Mosses, Alabama' with revid: 1175025748
# ORES scores for 'Moulton, Alabama' with revid: 1165894467
# ORES scores for 'Moundville, Alabama' with revid: 1166208667
# ORES scores for 'Mount Vernon, Alabama' with revid: 1166208775
# ORES scores for 'Mountain Brook, Alabama' with revid: 1172621297
# ORES scores for 'Mulga, Alabama' with revid: 1157496931
# ORES scores for 'Munford, Alabama' with revid: 1178871326
# ORES scores for 'Muscle Shoals, Alabama' with revid: 1178909921
# ORES scores for 'Myrtlewood, Alabama' with revid: 1166208882
# ORES scores for 'Napier Field, Alabama' with revid: 1166208894
# ORES scores for 'Natural Bridge, Alabama' with revid: 1166208941
# ORES scores for 'Nauvoo, Alabama' with revid: 1096820857
# ORES scores for 'Nectar, Alabama' with revid: 1166208963
# ORES scores for 'Needham, Alabama' with revid: 1166208968
# ORES scores for 'New Brockton, Alabama' with revid: 1166209021
# ORES scores for 'New Hope, Alabama' with revid: 1179883996
# ORES scores for 'New Site, Alabama' with revid: 1166209336
# ORES scores for 'Newbern, Alabama' with revid: 1180353697
# ORES scores for 'Newton, Alabama' with revid: 1166209571
# ORES scores for 'Newville, Alabama' with revid: 1177928995
# ORES scores for 'North Courtland, Alabama' with revid: 1166209704
# ORES scores for 'North Johns, Alabama' with revid: 1166209738
# ORES scores for 'Northport, Alabama' with revid: 1167817987
# ORES scores for 'Notasulga, Alabama' with revid: 1175854552
# ORES scores for 'Oak Grove, Alabama' with revid: 1124809704
# ORES scores for 'Oak Hill, Alabama' with revid: 1166209958
# ORES scores for 'Oakman, Alabama' with revid: 1174954255
# ORES scores for 'Odenville, Alabama' with revid: 1166210198
# ORES scores for 'Ohatchee, Alabama' with revid: 1166210252
# ORES scores for 'Oneonta, Alabama' with revid: 1166092446
# ORES scores for 'Onycha, Alabama' with revid: 1166210466
# ORES scores for 'Opelika, Alabama' with revid: 1165896665
# ORES scores for 'Opp, Alabama' with revid: 1165896683
# ORES scores for 'Orange Beach, Alabama' with revid: 1179725369
# ORES scores for 'Orrville, Alabama' with revid: 1175606582
# ORES scores for 'Owens Cross Roads, Alabama' with revid: 1172849762
# ORES scores for 'Oxford, Alabama' with revid: 1165896955
# ORES scores for 'Ozark, Alabama' with revid: 1175658038
# ORES scores for 'Paint Rock, Alabama' with revid: 1166210847
# ORES scores for 'Parrish, Alabama' with revid: 1166210982
# ORES scores for 'Pelham, Alabama' with revid: 1174024956
# ORES scores for 'Pell City, Alabama' with revid: 1171029165
# ORES scores for 'Pennington, Alabama' with revid: 1135170013
# ORES scores for 'Perdido Beach, Alabama' with revid: 1166211174
# ORES scores for 'Petrey, Alabama' with revid: 1096817791
# ORES scores for 'Phenix City, Alabama' with revid: 1160284984
# ORES scores for 'Phil Campbell, Alabama' with revid: 1176609767
# ORES scores for 'Pickensville, Alabama' with revid: 1166211277
# ORES scores for 'Piedmont, Alabama' with revid: 1174026676
# ORES scores for 'Pike Road, Alabama' with revid: 1170574167
# ORES scores for 'Pinckard, Alabama' with revid: 1166211323
# ORES scores for 'Pine Apple, Alabama' with revid: 1166211355
# ORES scores for 'Pine Hill, Alabama' with revid: 1166211367
# ORES scores for 'Pine Ridge, Alabama' with revid: 1166211388
# ORES scores for 'Pinson, Alabama' with revid: 1178582292
# ORES scores for 'Pisgah, Alabama' with revid: 1166211442
# ORES scores for 'Pleasant Grove, Alabama' with revid: 1177636010
# ORES scores for 'Pleasant Groves, Alabama' with revid: 1166229073
# ORES scores for 'Pollard, Alabama' with revid: 1166229176
# ORES scores for 'Powell, Alabama' with revid: 1166229333
# ORES scores for 'Prattville, Alabama' with revid: 1167939343
# ORES scores for 'Priceville, Alabama' with revid: 1166229409
# ORES scores for 'Prichard, Alabama' with revid: 1176865405
# ORES scores for 'Providence, Alabama' with revid: 1166229472
# ORES scores for 'Ragland, Alabama' with revid: 1166229540
# ORES scores for 'Rainbow City, Alabama' with revid: 1180291560
# ORES scores for 'Rainsville, Alabama' with revid: 1171084402
# ORES scores for 'Ranburne, Alabama' with revid: 1166229569
# ORES scores for 'Red Bay, Alabama' with revid: 1169333757
# ORES scores for 'Red Level, Alabama' with revid: 1166229671
# ORES scores for 'Reece City, Alabama' with revid: 1166229699
# ORES scores for 'Reform, Alabama' with revid: 1165899409
# ORES scores for 'Rehobeth, Alabama' with revid: 1172196089
# ORES scores for 'Repton, Alabama' with revid: 1166229759
# ORES scores for 'Ridgeville, Alabama' with revid: 1166229906
# ORES scores for 'River Falls, Alabama' with revid: 1166230019
# ORES scores for 'Riverside, Alabama' with revid: 1166230024
# ORES scores for 'Riverview, Alabama' with revid: 1166230040
# ORES scores for 'Roanoke, Alabama' with revid: 1165899878
# ORES scores for 'Robertsdale, Alabama' with revid: 1166314424
# ORES scores for 'Rockford, Alabama' with revid: 1169199856
# ORES scores for 'Rogersville, Alabama' with revid: 1166230187
# ORES scores for 'Rosa, Alabama' with revid: 1166230264
# ORES scores for 'Russellville, Alabama' with revid: 1165900503
# ORES scores for 'Rutledge, Alabama' with revid: 1166230534
# ORES scores for 'St. Florian, Alabama' with revid: 1166330128
# ORES scores for 'Samson, Alabama' with revid: 1165900688
# ORES scores for 'Sand Rock, Alabama' with revid: 1166230657
# ORES scores for 'Sanford, Alabama' with revid: 1166230687
# ORES scores for 'Saraland, Alabama' with revid: 1176013392
# ORES scores for 'Sardis City, Alabama' with revid: 1166230721
# ORES scores for 'Satsuma, Alabama' with revid: 1165900914
# ORES scores for 'Scottsboro, Alabama' with revid: 1174635424
# ORES scores for 'Section, Alabama' with revid: 1166230919
# ORES scores for 'Selma, Alabama' with revid: 1143473983
# ORES scores for 'Sheffield, Alabama' with revid: 1178910007
# ORES scores for 'Shiloh, DeKalb County, Alabama' with revid: 1166231236
# ORES scores for 'Shorter, Alabama' with revid: 1167174337
# ORES scores for 'Silas, Alabama' with revid: 1166231326
# ORES scores for 'Silverhill, Alabama' with revid: 1178521390
# ORES scores for 'Sipsey, Alabama' with revid: 1166231394
# ORES scores for 'Skyline, Alabama' with revid: 1166231421
# ORES scores for 'Slocomb, Alabama' with revid: 1165901938
# ORES scores for 'Smiths Station, Alabama' with revid: 1165901985
# ORES scores for 'Snead, Alabama' with revid: 1166231481
# ORES scores for 'Somerville, Alabama' with revid: 1166231524
# ORES scores for 'South Vinemont, Alabama' with revid: 1166329815
# ORES scores for 'Southside, Alabama' with revid: 1165902345
# ORES scores for 'Spanish Fort, Alabama' with revid: 1178909983
# ORES scores for 'Springville, Alabama' with revid: 1165902747
# ORES scores for 'Steele, Alabama' with revid: 1166330411
# ORES scores for 'Stevenson, Alabama' with revid: 1165903151
# ORES scores for 'Sulligent, Alabama' with revid: 1165903367
# ORES scores for 'Sumiton, Alabama' with revid: 1177623469
# ORES scores for 'Summerdale, Alabama' with revid: 1166330782
# ORES scores for 'Susan Moore, Alabama' with revid: 1166330933
# ORES scores for 'Sweet Water, Alabama' with revid: 1170589664
# ORES scores for 'Sylacauga, Alabama' with revid: 1176796677
# ORES scores for 'Sylvan Springs, Alabama' with revid: 1177624259
# ORES scores for 'Sylvania, Alabama' with revid: 1166331023
# ORES scores for 'Talladega Springs, Alabama' with revid: 1166331095
# ORES scores for 'Talladega, Alabama' with revid: 1165903654
# ORES scores for 'Tallassee, Alabama' with revid: 1151228134
# ORES scores for 'Tarrant, Alabama' with revid: 1177783643
# ORES scores for 'Taylor, Alabama' with revid: 1166331142
# ORES scores for 'Thomaston, Alabama' with revid: 1166331276
# ORES scores for 'Thomasville, Alabama' with revid: 1178846594
# ORES scores for 'Thorsby, Alabama' with revid: 1166331319
# ORES scores for 'Town Creek, Alabama' with revid: 1166331496
# ORES scores for 'Toxey, Alabama' with revid: 1166331527
# ORES scores for 'Trafford, Alabama' with revid: 1166331545
# ORES scores for 'Triana, Alabama' with revid: 1178614293
# ORES scores for 'Trinity, Alabama' with revid: 1166331634
# ORES scores for 'Troy, Alabama' with revid: 1176314436
# ORES scores for 'Trussville, Alabama' with revid: 1175000150
# ORES scores for 'Tuscaloosa, Alabama' with revid: 1179478135
# ORES scores for 'Tuscumbia, Alabama' with revid: 1178910105
# ORES scores for 'Tuskegee, Alabama' with revid: 1177701177
# ORES scores for 'Twin, Alabama' with revid: 1175521846
# ORES scores for 'Union Grove, Alabama' with revid: 1166331875
# ORES scores for 'Union Springs, Alabama' with revid: 1165905202
# ORES scores for 'Union, Alabama' with revid: 1178295657
# ORES scores for 'Uniontown, Alabama' with revid: 1165905237
# ORES scores for 'Valley, Alabama' with revid: 1165905995
# ORES scores for 'Valley Grande, Alabama' with revid: 1165905981
# ORES scores for 'Valley Head, Alabama' with revid: 1166331993
# ORES scores for 'Vance, Alabama' with revid: 1166332037
# ORES scores for 'Vernon, Alabama' with revid: 1165906151
# ORES scores for 'Vestavia Hills, Alabama' with revid: 1165906191
# ORES scores for 'Vina, Alabama' with revid: 1166332226
# ORES scores for 'Vincent, Alabama' with revid: 1165906276
# ORES scores for 'Vredenburgh, Alabama' with revid: 1166332292
# ORES scores for 'Wadley, Alabama' with revid: 1166332312
# ORES scores for 'Waldo, Alabama' with revid: 1166332371
# ORES scores for 'Walnut Grove, Alabama' with revid: 1166332454
# ORES scores for 'Warrior, Alabama' with revid: 1170770819
# ORES scores for 'Waterloo, Alabama' with revid: 1166332754
# ORES scores for 'Waverly, Alabama' with revid: 1132854855
# ORES scores for 'Weaver, Alabama' with revid: 1165906934
# ORES scores for 'Webb, Alabama' with revid: 1166332930
# ORES scores for 'Wedowee, Alabama' with revid: 1172981633
# ORES scores for 'West Blocton, Alabama' with revid: 1179078811
# ORES scores for 'West Jefferson, Alabama' with revid: 1166333114
# ORES scores for 'West Point, Alabama' with revid: 1166333164
# ORES scores for 'Westover, Alabama' with revid: 1165907320
# ORES scores for 'Wetumpka, Alabama' with revid: 1176205749
# ORES scores for 'White Hall, Alabama' with revid: 1166333467
# ORES scores for 'Wilsonville, Alabama' with revid: 1166333841
# ORES scores for 'Wilton, Alabama' with revid: 1166333844
# ORES scores for 'Winfield, Alabama' with revid: 1177270687
# ORES scores for 'Woodland, Alabama' with revid: 1166334268
# ORES scores for 'Woodstock, Alabama' with revid: 1166334349
# ORES scores for 'Woodville, Alabama' with revid: 1166334382
# ORES scores for 'Yellow Bluff, Alabama' with revid: 1166334559
# ORES scores for 'York, Alabama' with revid: 1171163639
# ORES scores for 'Adak, Alaska' with revid: 1174701601
# ORES scores for 'Akhiok, Alaska' with revid: 1176053029
# ORES scores for 'Akiak, Alaska' with revid: 1165506221
# ORES scores for 'Akutan, Alaska' with revid: 1174332990
# ORES scores for 'Alakanuk, Alaska' with revid: 1174333044
# ORES scores for 'Aleknagik, Alaska' with revid: 1174333266
# ORES scores for 'Allakaket, Alaska' with revid: 1166985589
# ORES scores for 'Ambler, Alaska' with revid: 1177436311
# ORES scores for 'Anaktuvuk Pass, Alaska' with revid: 1177430380
# ORES scores for 'Anchorage, Alaska' with revid: 1179842698
# ORES scores for 'Anderson, Alaska' with revid: 1165507165
# ORES scores for 'Angoon, Alaska' with revid: 1174449377
# ORES scores for 'Aniak, Alaska' with revid: 1174449433
# ORES scores for 'Anvik, Alaska' with revid: 1174449500
# ORES scores for 'Atka, Alaska' with revid: 1174453521
# ORES scores for 'Atqasuk, Alaska' with revid: 1175488757
# ORES scores for 'Bethel, Alaska' with revid: 1175739311
# ORES scores for 'Bettles, Alaska' with revid: 1165536061
# ORES scores for 'Brevig Mission, Alaska' with revid: 1178323045
# ORES scores for 'Buckland, Alaska' with revid: 1165537531
# ORES scores for 'Chefornak, Alaska' with revid: 1165539078
# ORES scores for 'Chevak, Alaska' with revid: 1176908860
# ORES scores for 'Chignik, Alaska' with revid: 1174403364
# ORES scores for 'Chuathbaluk, Alaska' with revid: 1165539392
# ORES scores for 'Clark's Point, Alaska' with revid: 1165539523
# ORES scores for 'Coffman Cove, Alaska' with revid: 1165644646
# ORES scores for 'Cold Bay, Alaska' with revid: 1173618968
# ORES scores for 'Cordova, Alaska' with revid: 1179094111
# ORES scores for 'Craig, Alaska' with revid: 1166077592
# ORES scores for 'Deering, Alaska' with revid: 1165646491
# ORES scores for 'Delta Junction, Alaska' with revid: 1173746973
# ORES scores for 'Dillingham, Alaska' with revid: 1169781442
# ORES scores for 'Diomede, Alaska' with revid: 1180286497
# ORES scores for 'Eagle, Alaska' with revid: 1171521339
# ORES scores for 'Edna Bay, Alaska' with revid: 1165647875
# ORES scores for 'Eek, Alaska' with revid: 1165647899
# ORES scores for 'Egegik, Alaska' with revid: 1165647916
# ORES scores for 'Ekwok, Alaska' with revid: 1165647928
# ORES scores for 'Elim, Alaska' with revid: 1178323179
# ORES scores for 'Emmonak, Alaska' with revid: 1165650698
# ORES scores for 'Fairbanks, Alaska' with revid: 1177325246
# ORES scores for 'False Pass, Alaska' with revid: 1160192738
# ORES scores for 'Fort Yukon, Alaska' with revid: 1169729372
# ORES scores for 'Galena, Alaska' with revid: 1175614529
# ORES scores for 'Gambell, Alaska' with revid: 1178323433
# ORES scores for 'Golovin, Alaska' with revid: 1178323552
# ORES scores for 'Goodnews Bay, Alaska' with revid: 1165748224
# ORES scores for 'Grayling, Alaska' with revid: 1165748594
# ORES scores for 'Gustavus, Alaska' with revid: 1177369669
# ORES scores for 'Holy Cross, Alaska' with revid: 1179078829
# ORES scores for 'Homer, Alaska' with revid: 1177395894
# ORES scores for 'Hoonah, Alaska' with revid: 1165750344
# ORES scores for 'Hooper Bay, Alaska' with revid: 1165750347
# ORES scores for 'Houston, Alaska' with revid: 1165750463
# ORES scores for 'Hughes, Alaska' with revid: 1165750555
# ORES scores for 'Huslia, Alaska' with revid: 1174931151
# ORES scores for 'Hydaburg, Alaska' with revid: 1165750723
# ORES scores for 'Juneau, Alaska' with revid: 1180301476
# ORES scores for 'Kachemak, Alaska' with revid: 1165751412
# ORES scores for 'Kake, Alaska' with revid: 1151995274
# ORES scores for 'Kaktovik, Alaska' with revid: 1167643705
# ORES scores for 'Kaltag, Alaska' with revid: 1165751831
# ORES scores for 'Kasaan, Alaska' with revid: 1165751881
# ORES scores for 'Kenai, Alaska' with revid: 1179083176
# ORES scores for 'Ketchikan, Alaska' with revid: 1178738064
# ORES scores for 'Kiana, Alaska' with revid: 1165752156
# ORES scores for 'King Cove, Alaska' with revid: 1165752232
# ORES scores for 'Kivalina, Alaska' with revid: 1167306947
# ORES scores for 'Klawock, Alaska' with revid: 1165752344
# ORES scores for 'Kobuk, Alaska' with revid: 1165752375
# ORES scores for 'Kodiak, Alaska' with revid: 1179271887
# ORES scores for 'Kotlik, Alaska' with revid: 1165752392
# ORES scores for 'Kotzebue, Alaska' with revid: 1174601049
# ORES scores for 'Koyuk, Alaska' with revid: 1178323608
# ORES scores for 'Koyukuk, Alaska' with revid: 1165752404
# ORES scores for 'Kupreanof, Alaska' with revid: 1165752424
# ORES scores for 'Kwethluk, Alaska' with revid: 1165752432
# ORES scores for 'Larsen Bay, Alaska' with revid: 1165889278
# ORES scores for 'Lower Kalskag, Alaska' with revid: 1165891507
# ORES scores for 'Manokotak, Alaska' with revid: 1165892011
# ORES scores for 'Marshall, Alaska' with revid: 1165892419
# ORES scores for 'McGrath, Alaska' with revid: 1165892805
# ORES scores for 'Mekoryuk, Alaska' with revid: 1165893071
# ORES scores for 'Mountain Village, Alaska' with revid: 1165894670
# ORES scores for 'Napakiak, Alaska' with revid: 1165894869
# ORES scores for 'Napaskiak, Alaska' with revid: 1165894871
# ORES scores for 'Nenana, Alaska' with revid: 1180165147
# ORES scores for 'New Stuyahok, Alaska' with revid: 1165895355
# ORES scores for 'Newhalen, Alaska' with revid: 1165895462
# ORES scores for 'Nightmute, Alaska' with revid: 1165895575
# ORES scores for 'Nikolai, Alaska' with revid: 1165895576
# ORES scores for 'Nome, Alaska' with revid: 1180266901
# ORES scores for 'Nondalton, Alaska' with revid: 1170380383
# ORES scores for 'Noorvik, Alaska' with revid: 1165895660
# ORES scores for 'North Pole, Alaska' with revid: 1171106754
# ORES scores for 'Nuiqsut, Alaska' with revid: 1177353920
# ORES scores for 'Nulato, Alaska' with revid: 1165896076
# ORES scores for 'Nunam Iqua, Alaska' with revid: 1165896079
# ORES scores for 'Nunapitchuk, Alaska' with revid: 1177372546
# ORES scores for 'Old Harbor, Alaska' with revid: 1165896477
# ORES scores for 'Ouzinkie, Alaska' with revid: 1178021269
# ORES scores for 'Palmer, Alaska' with revid: 1178249435
# ORES scores for 'Pelican, Alaska' with revid: 1169144269
# ORES scores for 'Pilot Point, Alaska' with revid: 1165897826
# ORES scores for 'Pilot Station, Alaska' with revid: 1165897836
# ORES scores for 'Platinum, Alaska' with revid: 1176310844
# ORES scores for 'Point Hope, Alaska' with revid: 1175174815
# ORES scores for 'Port Alexander, Alaska' with revid: 1165898418
# ORES scores for 'Port Heiden, Alaska' with revid: 1176004478
# ORES scores for 'Port Lions, Alaska' with revid: 1165898446
# ORES scores for 'Quinhagak, Alaska' with revid: 1172626458
# ORES scores for 'Ruby, Alaska' with revid: 1165900403
# ORES scores for 'Russian Mission, Alaska' with revid: 1165900513
# ORES scores for 'Saint Paul, Alaska' with revid: 16043073
# ORES scores for 'Sand Point, Alaska' with revid: 1175877401
# ORES scores for 'Savoonga, Alaska' with revid: 1178323891
# ORES scores for 'Saxman, Alaska' with revid: 1167268500
# ORES scores for 'Scammon Bay, Alaska' with revid: 1165900948
# ORES scores for 'Selawik, Alaska' with revid: 1165901173
# ORES scores for 'Seldovia, Alaska' with revid: 1168917631
# ORES scores for 'Seward, Alaska' with revid: 1165901331
# ORES scores for 'Shageluk, Alaska' with revid: 1165901362
# ORES scores for 'Shaktoolik, Alaska' with revid: 1178324004
# ORES scores for 'Shishmaref, Alaska' with revid: 1179637642
# ORES scores for 'Shungnak, Alaska' with revid: 1165901710
# ORES scores for 'Sitka, Alaska' with revid: 1178737193
# ORES scores for 'Soldotna, Alaska' with revid: 1178626084
# ORES scores for 'St. George, Alaska' with revid: 1165902860
# ORES scores for 'St. Mary's, Alaska' with revid: 1165902930
# ORES scores for 'St. Michael, Alaska' with revid: 1179637630
# ORES scores for 'Stebbins, Alaska' with revid: 1178324371
# ORES scores for 'Tanana, Alaska' with revid: 1165903695
# ORES scores for 'Teller, Alaska' with revid: 1178324450
# ORES scores for 'Tenakee Springs, Alaska' with revid: 1160022935
# ORES scores for 'Thorne Bay, Alaska' with revid: 1165904083
# ORES scores for 'Togiak, Alaska' with revid: 1165904528
# ORES scores for 'Toksook Bay, Alaska' with revid: 1165904534
# ORES scores for 'Unalakleet, Alaska' with revid: 1179637652
# ORES scores for 'Unalaska, Alaska' with revid: 1176638051
# ORES scores for 'Upper Kalskag, Alaska' with revid: 1166366344
# ORES scores for 'Utqiaġvik' with revid: 1134590975
# ORES scores for 'Valdez, Alaska' with revid: 1177025566
# ORES scores for 'Wainwright, Alaska' with revid: 1168069408
# ORES scores for 'Wales, Alaska' with revid: 1178324810
# ORES scores for 'Wasilla, Alaska' with revid: 1162414873
# ORES scores for 'Whale Pass, Alaska' with revid: 1166367587
# ORES scores for 'White Mountain, Alaska' with revid: 1178324863
# ORES scores for 'Whittier, Alaska' with revid: 1180207100
# ORES scores for 'Wrangell, Alaska' with revid: 1178736535
# ORES scores for 'Apache Junction, Arizona' with revid: 1172275090
# ORES scores for 'Avondale, Arizona' with revid: 1172274660
# ORES scores for 'Benson, Arizona' with revid: 1177264416
# ORES scores for 'Bisbee, Arizona' with revid: 1179974772
# ORES scores for 'Buckeye, Arizona' with revid: 1179549390
# ORES scores for 'Bullhead City, Arizona' with revid: 1179668677
# ORES scores for 'Camp Verde, Arizona' with revid: 1172004828
# ORES scores for 'Carefree, Arizona' with revid: 1160780528
# ORES scores for 'Casa Grande, Arizona' with revid: 1158938630
# ORES scores for 'Cave Creek, Arizona' with revid: 1160299409
# ORES scores for 'Chandler, Arizona' with revid: 1179696082
# ORES scores for 'Chino Valley, Arizona' with revid: 1165071501
# ORES scores for 'Clarkdale, Arizona' with revid: 1179793089
# ORES scores for 'Clifton, Arizona' with revid: 1166754568
# ORES scores for 'Colorado City, Arizona' with revid: 1169856603
# ORES scores for 'Coolidge, Arizona' with revid: 1176316536
# ORES scores for 'Cottonwood, Arizona' with revid: 1165645327
# ORES scores for 'Dewey-Humboldt, Arizona' with revid: 875227915
# ORES scores for 'Douglas, Arizona' with revid: 1179839136
# ORES scores for 'Duncan, Arizona' with revid: 1166337654
# ORES scores for 'Eagar, Arizona' with revid: 1173734731
# ORES scores for 'El Mirage, Arizona' with revid: 1173393974
# ORES scores for 'Eloy, Arizona' with revid: 1154855908
# ORES scores for 'Flagstaff, Arizona' with revid: 1178421971
# ORES scores for 'Florence, Arizona' with revid: 1176287706
# ORES scores for 'Fountain Hills, Arizona' with revid: 1177291848
# ORES scores for 'Fredonia, Arizona' with revid: 1165987701
# ORES scores for 'Gila Bend, Arizona' with revid: 1178205332
# ORES scores for 'Gilbert, Arizona' with revid: 1178919942
# ORES scores for 'Glendale, Arizona' with revid: 1178897696
# ORES scores for 'Globe, Arizona' with revid: 1175877749
# ORES scores for 'Goodyear, Arizona' with revid: 1173050898
# ORES scores for 'Guadalupe, Arizona' with revid: 1163900551
# ORES scores for 'Hayden, Arizona' with revid: 1153225829
# ORES scores for 'Holbrook, Arizona' with revid: 1176281297
# ORES scores for 'Huachuca City, Arizona' with revid: 1162263927
# ORES scores for 'Jerome, Arizona' with revid: 1167180118
# ORES scores for 'Kearny, Arizona' with revid: 1096893627
# ORES scores for 'Kingman, Arizona' with revid: 1174652133
# ORES scores for 'Lake Havasu City, Arizona' with revid: 1173659575
# ORES scores for 'Litchfield Park, Arizona' with revid: 1176169080
# ORES scores for 'Mammoth, Arizona' with revid: 1169570180
# ORES scores for 'Marana, Arizona' with revid: 1174937558
# ORES scores for 'Maricopa, Arizona' with revid: 1177266886
# ORES scores for 'Mesa, Arizona' with revid: 1179718337
# ORES scores for 'Miami, Arizona' with revid: 1156414740
# ORES scores for 'Nogales, Arizona' with revid: 1179850250
# ORES scores for 'Oro Valley, Arizona' with revid: 1177358050
# ORES scores for 'Page, Arizona' with revid: 1173488096
# ORES scores for 'Paradise Valley, Arizona' with revid: 1180082156
# ORES scores for 'Parker, Arizona' with revid: 1152788081
# ORES scores for 'Patagonia, Arizona' with revid: 1169934143
# ORES scores for 'Payson, Arizona' with revid: 1173861091
# ORES scores for 'Peoria, Arizona' with revid: 1178906818
# ORES scores for 'Phoenix, Arizona' with revid: 1180348158
# ORES scores for 'Pima, Arizona' with revid: 1106236473
# ORES scores for 'Pinetop-Lakeside, Arizona' with revid: 1180210290
# ORES scores for 'Prescott, Arizona' with revid: 1178267796
# ORES scores for 'Prescott Valley, Arizona' with revid: 1156718858
# ORES scores for 'Quartzsite, Arizona' with revid: 1160322253
# ORES scores for 'Queen Creek, Arizona' with revid: 1173813551
# ORES scores for 'Safford, Arizona' with revid: 1173054325
# ORES scores for 'Sahuarita, Arizona' with revid: 1169666739
# ORES scores for 'San Luis, Arizona' with revid: 1176401746
# ORES scores for 'Scottsdale, Arizona' with revid: 1179949854
# ORES scores for 'Sedona, Arizona' with revid: 1179932393
# ORES scores for 'Show Low, Arizona' with revid: 1180210337
# ORES scores for 'Sierra Vista, Arizona' with revid: 1174449402
# ORES scores for 'Snowflake, Arizona' with revid: 1180210361
# ORES scores for 'Somerton, Arizona' with revid: 1179358668
# ORES scores for 'South Tucson, Arizona' with revid: 1170788597
# ORES scores for 'Springerville, Arizona' with revid: 1166889274
# ORES scores for 'St. Johns, Arizona' with revid: 1178794263
# ORES scores for 'Star Valley, Arizona' with revid: 1139304335
# ORES scores for 'Superior, Arizona' with revid: 1157359445
# ORES scores for 'Surprise, Arizona' with revid: 1177976702
# ORES scores for 'Taylor, Arizona' with revid: 1179261663
# ORES scores for 'Tempe, Arizona' with revid: 1179728906
# ORES scores for 'Thatcher, Arizona' with revid: 1147369251
# ORES scores for 'Tolleson, Arizona' with revid: 1179981845
# ORES scores for 'Tombstone, Arizona' with revid: 1174497536
# ORES scores for 'Tucson, Arizona' with revid: 1180217682
# ORES scores for 'Tusayan, Arizona' with revid: 1166361496
# ORES scores for 'Wellton, Arizona' with revid: 1157015772
# ORES scores for 'Wickenburg, Arizona' with revid: 1162036938
# ORES scores for 'Willcox, Arizona' with revid: 1179224228
# ORES scores for 'Williams, Arizona' with revid: 1178123655
# ORES scores for 'Winkelman, Arizona' with revid: 1164044104
# ORES scores for 'Winslow, Arizona' with revid: 1175280540
# ORES scores for 'Youngtown, Arizona' with revid: 1176064323
# ORES scores for 'Yuma, Arizona' with revid: 1177239057
# ORES scores for 'Adona, Arkansas' with revid: 1171163261
# ORES scores for 'Alexander, Arkansas' with revid: 1170293677
# ORES scores for 'Alicia, Arkansas' with revid: 1165909698
# ORES scores for 'Allport, Arkansas' with revid: 1165909727
# ORES scores for 'Alma, Arkansas' with revid: 1175126769
# ORES scores for 'Almyra, Arkansas' with revid: 1165909758
# ORES scores for 'Alpena, Arkansas' with revid: 1177693232
# ORES scores for 'Altheimer, Arkansas' with revid: 1174297869
# ORES scores for 'Altus, Arkansas' with revid: 1165506702
# ORES scores for 'Amagon, Arkansas' with revid: 1170495752
# ORES scores for 'Amity, Arkansas' with revid: 1165507102
# ORES scores for 'Anthonyville, Arkansas' with revid: 1173351183
# ORES scores for 'Antoine, Arkansas' with revid: 1166014348
# ORES scores for 'Arkadelphia, Arkansas' with revid: 1170627594
# ORES scores for 'Arkansas City, Arkansas' with revid: 1166014483
# ORES scores for 'Ash Flat, Arkansas' with revid: 1176909406
# ORES scores for 'Ashdown, Arkansas' with revid: 1176429760
# ORES scores for 'Atkins, Arkansas' with revid: 1165507792
# ORES scores for 'Aubrey, Arkansas' with revid: 1166014726
# ORES scores for 'Augusta, Arkansas' with revid: 1165507995
# ORES scores for 'Austin, Arkansas' with revid: 1165508109
# ORES scores for 'Avoca, Arkansas' with revid: 1166014855
# ORES scores for 'Bald Knob, Arkansas' with revid: 1165508267
# ORES scores for 'Banks, Arkansas' with revid: 1166015001
# ORES scores for 'Barling, Arkansas' with revid: 1165508385
# ORES scores for 'Bassett, Arkansas' with revid: 1166015125
# ORES scores for 'Batesville, Arkansas' with revid: 1176616588
# ORES scores for 'Bauxite, Arkansas' with revid: 1166015145
# ORES scores for 'Bay, Arkansas' with revid: 1174175417
# ORES scores for 'Bearden, Arkansas' with revid: 1165508810
# ORES scores for 'Beaver, Arkansas' with revid: 1178137595
# ORES scores for 'Beebe, Arkansas' with revid: 1165508973
# ORES scores for 'Beedeville, Arkansas' with revid: 1165909247
# ORES scores for 'Bella Vista, Arkansas' with revid: 1174777407
# ORES scores for 'Bellefonte, Arkansas' with revid: 1166015341
# ORES scores for 'Belleville, Arkansas' with revid: 1165509126
# ORES scores for 'Ben Lomond, Arkansas' with revid: 1177682271
# ORES scores for 'Benton, Arkansas' with revid: 1165535715
# ORES scores for 'Bentonville, Arkansas' with revid: 1177677430
# ORES scores for 'Bergman, Arkansas' with revid: 1166015461
# ORES scores for 'Berryville, Arkansas' with revid: 1177935177
# ORES scores for 'Bethel Heights, Arkansas' with revid: 1165536050
# ORES scores for 'Big Flat, Arkansas' with revid: 1166015659
# ORES scores for 'Bigelow, Arkansas' with revid: 1166015683
# ORES scores for 'Biggers, Arkansas' with revid: 1170718351
# ORES scores for 'Birdsong, Arkansas' with revid: 1166015727
# ORES scores for 'Black Oak, Arkansas' with revid: 1159482487
# ORES scores for 'Black Rock, Arkansas' with revid: 1165536235
# ORES scores for 'Black Springs, Arkansas' with revid: 1166015767
# ORES scores for 'Blevins, Arkansas' with revid: 1165536367
# ORES scores for 'Blue Eye, Arkansas' with revid: 1175715312
# ORES scores for 'Blue Mountain, Arkansas' with revid: 1166015895
# ORES scores for 'Bluff City, Arkansas' with revid: 1166015909
# ORES scores for 'Blytheville, Arkansas' with revid: 1165536510
# ORES scores for 'Bodcaw, Arkansas' with revid: 1166015937
# ORES scores for 'Bonanza, Arkansas' with revid: 1165536596
# ORES scores for 'Bono, Arkansas' with revid: 1177663088
# ORES scores for 'Booneville, Arkansas' with revid: 1165536649
# ORES scores for 'Bradford, Arkansas' with revid: 1165536803
# ORES scores for 'Bradley, Arkansas' with revid: 1165536818
# ORES scores for 'Branch, Arkansas' with revid: 1165536842
# ORES scores for 'Briarcliff, Arkansas' with revid: 1172560462
# ORES scores for 'Brinkley, Arkansas' with revid: 1166316475
# ORES scores for 'Brookland, Arkansas' with revid: 1165537303
# ORES scores for 'Bryant, Arkansas' with revid: 1174650298
# ORES scores for 'Buckner, Arkansas' with revid: 1166016717
# ORES scores for 'Bull Shoals, Arkansas' with revid: 1174392174
# ORES scores for 'Burdette, Arkansas' with revid: 1166016776
# ORES scores for 'Cabot, Arkansas' with revid: 1177251917
# ORES scores for 'Caddo Valley, Arkansas' with revid: 1166016960
# ORES scores for 'Caldwell, Arkansas' with revid: 1165537922
# ORES scores for 'Cale, Arkansas' with revid: 1166016994
# ORES scores for 'Calico Rock, Arkansas' with revid: 1165537951
# ORES scores for 'Calion, Arkansas' with revid: 1165537973
# ORES scores for 'Camden, Arkansas' with revid: 1163828520
# ORES scores for 'Cammack Village, Arkansas' with revid: 1170076116
# ORES scores for 'Campbell Station, Arkansas' with revid: 1165538091
# ORES scores for 'Caraway, Arkansas' with revid: 1165538273
# ORES scores for 'Carlisle, Arkansas' with revid: 1165538323
# ORES scores for 'Carthage, Arkansas' with revid: 1165538485
# ORES scores for 'Casa, Arkansas' with revid: 1166017387
# ORES scores for 'Cash, Arkansas' with revid: 1165538542
# ORES scores for 'Caulksville, Arkansas' with revid: 1166017466
# ORES scores for 'Cave City, Arkansas' with revid: 1165538627
# ORES scores for 'Cave Springs, Arkansas' with revid: 1177782424
# ORES scores for 'Cedarville, Arkansas' with revid: 1165538753
# ORES scores for 'Centerton, Arkansas' with revid: 1165538814
# ORES scores for 'Central City, Arkansas' with revid: 1166017560
# ORES scores for 'Charleston, Arkansas' with revid: 1174517840
# ORES scores for 'Cherokee Village, Arkansas' with revid: 1165539118
# ORES scores for 'Cherry Valley, Arkansas' with revid: 1165539146
# ORES scores for 'Chester, Arkansas' with revid: 1166017778
# ORES scores for 'Chidester, Arkansas' with revid: 1165539217
# ORES scores for 'Clarendon, Arkansas' with revid: 1165539502
# ORES scores for 'Clarkedale, Arkansas' with revid: 1165539532
# ORES scores for 'Clarksville, Arkansas' with revid: 1148922313
# ORES scores for 'Clinton, Arkansas' with revid: 1171862894
# ORES scores for 'Coal Hill, Arkansas' with revid: 1147578559
# ORES scores for 'Colt, Arkansas' with revid: 1165644840
# ORES scores for 'Concord, Arkansas' with revid: 1166018683
# ORES scores for 'Conway, Arkansas' with revid: 1174981561
# ORES scores for 'Corinth, Arkansas' with revid: 1166018817
# ORES scores for 'Corning, Arkansas' with revid: 1165645220
# ORES scores for 'Cotter, Arkansas' with revid: 1165645303
# ORES scores for 'Cotton Plant, Arkansas' with revid: 1165645312
# ORES scores for 'Cove, Arkansas' with revid: 1177681894
# ORES scores for 'Coy, Arkansas' with revid: 1166019016
# ...
# ORES scores for 'Napavine, Washington' with revid: 1177071660
# ORES scores for 'Newcastle, Washington' with revid: 1175609833
# ORES scores for 'Newport, Washington' with revid: 1179543153
# ORES scores for 'Nooksack, Washington' with revid: 1166787552
# ORES scores for 'Normandy Park, Washington' with revid: 1165895708
# ORES scores for 'North Bend, Washington' with revid: 1178960646
# ORES scores for 'North Bonneville, Washington' with revid: 1165895751
# ORES scores for 'Oak Harbor, Washington' with revid: 1180299327
# ORES scores for 'Oakville, Washington' with revid: 1165896264
# ORES scores for 'Ocean Shores, Washington' with revid: 1170496394
# ORES scores for 'Okanogan, Washington' with revid: 1165896447
# ORES scores for 'Olympia, Washington' with revid: 1180349261
# ORES scores for 'Omak, Washington' with revid: 1177018947
# ORES scores for 'Oroville, Washington' with revid: 1169212145
# ORES scores for 'Orting, Washington' with revid: 1162810831
# ORES scores for 'Othello, Washington' with revid: 1172095328
# ORES scores for 'Pacific, Washington' with revid: 1174439211
# ORES scores for 'Palouse, Washington' with revid: 1165897119
# ORES scores for 'Pasco, Washington' with revid: 1180370500
# ORES scores for 'Pateros, Washington' with revid: 1165897326
# ORES scores for 'Pomeroy, Washington' with revid: 1179461862
# ORES scores for 'Port Angeles, Washington' with revid: 1178431888
# ORES scores for 'Port Orchard, Washington' with revid: 1179567904
# ORES scores for 'Port Townsend, Washington' with revid: 1177553935
# ORES scores for 'Poulsbo, Washington' with revid: 1173235931
# ORES scores for 'Prescott, Washington' with revid: 1165898711
# ORES scores for 'Prosser, Washington' with revid: 1165898851
# ORES scores for 'Pullman, Washington' with revid: 1178759561
# ORES scores for 'Puyallup, Washington' with revid: 1179241498
# ORES scores for 'Quincy, Washington' with revid: 1171007277
# ORES scores for 'Rainier, Washington' with revid: 1177992041
# ORES scores for 'Raymond, Washington' with revid: 1173012193
# ORES scores for 'Redmond, Washington' with revid: 1180370503
# ORES scores for 'Renton, Washington' with revid: 1180345292
# ORES scores for 'Republic, Washington' with revid: 1170441057
# ORES scores for 'Richland, Washington' with revid: 1180370502
# ORES scores for 'Ridgefield, Washington' with revid: 1170486276
# ORES scores for 'Ritzville, Washington' with revid: 1165899827
# ORES scores for 'Rock Island, Washington' with revid: 1165899963
# ORES scores for 'Roslyn, Washington' with revid: 1177746829
# ORES scores for 'Roy, Washington' with revid: 1174872804
# ORES scores for 'Royal City, Washington' with revid: 1169205917
# ORES scores for 'Ruston, Washington' with revid: 1165900520
# ORES scores for 'Sammamish, Washington' with revid: 1180419191
# ORES scores for 'SeaTac, Washington' with revid: 1170920088
# ORES scores for 'Seattle' with revid: 1180343250
# ORES scores for 'Sedro-Woolley, Washington' with revid: 1143599287
# ORES scores for 'Selah, Washington' with revid: 1165901168
# ORES scores for 'Sequim, Washington' with revid: 1178321304
# ORES scores for 'Shelton, Washington' with revid: 1172720742
# ORES scores for 'Shoreline, Washington' with revid: 1180370496
# ORES scores for 'Snohomish, Washington' with revid: 1177218247
# ORES scores for 'Snoqualmie, Washington' with revid: 1177667560
# ORES scores for 'Soap Lake, Washington' with revid: 1165902024
# ORES scores for 'South Bend, Washington' with revid: 1169369179
# ORES scores for 'Spangle, Washington' with revid: 1165902355
# ORES scores for 'Spokane, Washington' with revid: 1180343069
# ORES scores for 'Spokane Valley, Washington' with revid: 1180370501
# ORES scores for 'Sprague, Washington' with revid: 1165902637
# ORES scores for 'Stanwood, Washington' with revid: 1179386060
# ORES scores for 'Stevenson, Washington' with revid: 1179690562
# ORES scores for 'Sultan, Washington' with revid: 1176455318
# ORES scores for 'Sumas, Washington' with revid: 1175196167
# ORES scores for 'Sumner, Washington' with revid: 1178431766
# ORES scores for 'Sunnyside, Washington' with revid: 1160221492
# ORES scores for 'Tacoma, Washington' with revid: 1180342883
# ORES scores for 'Tekoa, Washington' with revid: 1178732073
# ORES scores for 'Tenino, Washington' with revid: 1170561645
# ORES scores for 'Tieton, Washington' with revid: 1165904119
# ORES scores for 'Toledo, Washington' with revid: 1177248577
# ORES scores for 'Tonasket, Washington' with revid: 1170445909
# ORES scores for 'Toppenish, Washington' with revid: 1174073273
# ORES scores for 'Tukwila, Washington' with revid: 1175664721
# ORES scores for 'Tumwater, Washington' with revid: 1176603117
# ORES scores for 'Union Gap, Washington' with revid: 1165971500
# ORES scores for 'University Place, Washington' with revid: 1165905281
# ORES scores for 'Vader, Washington' with revid: 1170714265
# ORES scores for 'Vancouver, Washington' with revid: 1180370507
# ORES scores for 'Waitsburg, Washington' with revid: 1165906402
# ORES scores for 'Walla Walla, Washington' with revid: 1178706033
# ORES scores for 'Wapato, Washington' with revid: 1164589426
# ORES scores for 'Warden, Washington' with revid: 1142539863
# ORES scores for 'Washougal, Washington' with revid: 1174771932
# ORES scores for 'Wenatchee, Washington' with revid: 1176317917
# ORES scores for 'West Richland, Washington' with revid: 1165907225
# ORES scores for 'Westport, Washington' with revid: 1165907339
# ORES scores for 'White Salmon, Washington' with revid: 1165907493
# ORES scores for 'Winlock, Washington' with revid: 1177071279
# ORES scores for 'Woodinville, Washington' with revid: 1175217947
# ORES scores for 'Woodland, Washington' with revid: 1143837012
# ORES scores for 'Woodway, Washington' with revid: 1172396223
# ORES scores for 'Yakima, Washington' with revid: 1180345975
# ORES scores for 'Yelm, Washington' with revid: 1168282505
# ORES scores for 'Zillah, Washington' with revid: 1147481395
# ORES scores for 'Albion, Washington' with revid: 1180311473
# ORES scores for 'Almira, Washington' with revid: 1135299836
# ORES scores for 'Beaux Arts Village, Washington' with revid: 1172086570
# ORES scores for 'Bucoda, Washington' with revid: 1170561466
# ORES scores for 'Carbonado, Washington' with revid: 1173465882
# ORES scores for 'Cathlamet, Washington' with revid: 1179285706
# ORES scores for 'Colton, Washington' with revid: 1172351383
# ORES scores for 'Conconully, Washington' with revid: 1166018676
# ORES scores for 'Concrete, Washington' with revid: 1166018706
# ORES scores for 'Coulee City, Washington' with revid: 1160978587
# ORES scores for 'Coulee Dam, Washington' with revid: 1166018943
# ORES scores for 'Coupeville, Washington' with revid: 1176606562
# ORES scores for 'Creston, Washington' with revid: 1176434473
# ORES scores for 'Cusick, Washington' with revid: 1166066260
# ORES scores for 'Darrington, Washington' with revid: 1176649206
# ORES scores for 'Eatonville, Washington' with revid: 1166067429
# ORES scores for 'Elmer City, Washington' with revid: 1166067649
# ORES scores for 'Endicott, Washington' with revid: 1166067711
# ORES scores for 'Fairfield, Washington' with revid: 1175259348
# ORES scores for 'Farmington, Washington' with revid: 1166068113
# ORES scores for 'Friday Harbor, Washington' with revid: 1159624428
# ORES scores for 'Garfield, Washington' with revid: 1176035238
# ORES scores for 'Hamilton, Washington' with revid: 1166180336
# ORES scores for 'Harrah, Washington' with revid: 1166180538
# ORES scores for 'Hartline, Washington' with revid: 1166180634
# ORES scores for 'Hatton, Washington' with revid: 1166180703
# ORES scores for 'Hunts Point, Washington' with revid: 1169208328
# ORES scores for 'Index, Washington' with revid: 1179878050
# ORES scores for 'Ione, Washington' with revid: 1177218605
# ORES scores for 'Krupp, Washington' with revid: 875621555
# ORES scores for 'La Conner, Washington' with revid: 1175973831
# ORES scores for 'LaCrosse, Washington' with revid: 16445987
# ORES scores for 'Lamont, Washington' with revid: 1166205477
# ORES scores for 'Latah, Washington' with revid: 1166205596
# ORES scores for 'Lind, Washington' with revid: 1166206020
# ORES scores for 'Lyman, Washington' with revid: 1166206536
# ORES scores for 'Malden, Washington' with revid: 1166206711
# ORES scores for 'Mansfield, Washington' with revid: 1166206788
# ORES scores for 'Marcus, Washington' with revid: 1166206861
# ORES scores for 'Metaline, Washington' with revid: 1166207600
# ORES scores for 'Metaline Falls, Washington' with revid: 1133764730
# ORES scores for 'Naches, Washington' with revid: 1166208883
# ORES scores for 'Nespelem, Washington' with revid: 1166208994
# ORES scores for 'Northport, Washington' with revid: 1166209845
# ORES scores for 'Oakesdale, Washington' with revid: 1166209991
# ORES scores for 'Odessa, Washington' with revid: 1166210212
# ORES scores for 'Pe Ell, Washington' with revid: 1167777500
# ORES scores for 'Reardan, Washington' with revid: 1177435713
# ORES scores for 'Riverside, Washington' with revid: 1166230035
# ORES scores for 'Rockford, Washington' with revid: 1166230111
# ORES scores for 'Rosalia, Washington' with revid: 1166230267
# ORES scores for 'St. John, Washington' with revid: 1171248340
# ORES scores for 'Skykomish, Washington' with revid: 1172491206
# ORES scores for 'South Cle Elum, Washington' with revid: 1166329643
# ORES scores for 'South Prairie, Washington' with revid: 1166329795
# ORES scores for 'Springdale, Washington' with revid: 1166330015
# ORES scores for 'Starbuck, Washington' with revid: 1166330366
# ORES scores for 'Steilacoom, Washington' with revid: 1180310881
# ORES scores for 'Twisp, Washington' with revid: 1166331806
# ORES scores for 'Uniontown, Washington' with revid: 1176758698
# ORES scores for 'Washtucna, Washington' with revid: 1166332726
# ORES scores for 'Waterville, Washington' with revid: 1166332802
# ORES scores for 'Waverly, Washington' with revid: 1166332873
# ORES scores for 'Wilbur, Washington' with revid: 1166333648
# ORES scores for 'Wilkeson, Washington' with revid: 1176401350
# ORES scores for 'Wilson Creek, Washington' with revid: 1134835942
# ORES scores for 'Winthrop, Washington' with revid: 1177587687
# ORES scores for 'Yacolt, Washington' with revid: 1175857682
# ORES scores for 'Yarrow Point, Washington' with revid: 1173231308
# ORES scores for 'Afton, Wyoming' with revid: 1171182190
# ORES scores for 'Albin, Wyoming' with revid: 1165909593
# ORES scores for 'Alpine, Wyoming' with revid: 1166845348
# ORES scores for 'Baggs, Wyoming' with revid: 1166014924
# ORES scores for 'Bairoil, Wyoming' with revid: 1176634311
# ORES scores for 'Bar Nunn, Wyoming' with revid: 1166015010
# ORES scores for 'Basin, Wyoming' with revid: 1166347823
# ORES scores for 'Bear River, Wyoming' with revid: 1166015205
# ORES scores for 'Big Piney, Wyoming' with revid: 1157170629
# ORES scores for 'Buffalo, Wyoming' with revid: 1166345853
# ORES scores for 'Burlington, Wyoming' with revid: 1166016832
# ORES scores for 'Burns, Wyoming' with revid: 1166016862
# ORES scores for 'Byron, Wyoming' with revid: 1169864946
# ORES scores for 'Casper, Wyoming' with revid: 1179835289
# ORES scores for 'Cheyenne, Wyoming' with revid: 1180304524
# ORES scores for 'Chugwater, Wyoming' with revid: 1177388483
# ORES scores for 'Clearmont, Wyoming' with revid: 1166018144
# ORES scores for 'Cody, Wyoming' with revid: 1170712948
# ORES scores for 'Cokeville, Wyoming' with revid: 1166749411
# ORES scores for 'Cowley, Wyoming' with revid: 1172969586
# ORES scores for 'Dayton, Wyoming' with revid: 1166066502
# ORES scores for 'Deaver, Wyoming' with revid: 1166066518
# ORES scores for 'Diamondville, Wyoming' with revid: 1166748230
# ORES scores for 'Dixon, Wyoming' with revid: 1166066971
# ORES scores for 'Douglas, Wyoming' with revid: 1174471289
# ORES scores for 'Dubois, Wyoming' with revid: 1166067093
# ORES scores for 'East Thermopolis, Wyoming' with revid: 1166067274
# ORES scores for 'Edgerton, Wyoming' with revid: 1166067471
# ORES scores for 'Elk Mountain, Wyoming' with revid: 1158729030
# ORES scores for 'Encampment, Wyoming' with revid: 1166067707
# ORES scores for 'Evanston, Wyoming' with revid: 1178126053
# ORES scores for 'Evansville, Wyoming' with revid: 1166067917
# ORES scores for 'Fort Laramie, Wyoming' with revid: 1135797633
# ORES scores for 'Frannie, Wyoming' with revid: 1166068677
# ORES scores for 'Gillette, Wyoming' with revid: 1179836011
# ORES scores for 'Glendo, Wyoming' with revid: 1166069486
# ORES scores for 'Glenrock, Wyoming' with revid: 1169218774
# ORES scores for 'Granger, Wyoming' with revid: 1166069720
# ORES scores for 'Green River, Wyoming' with revid: 1168463339
# ORES scores for 'Greybull, Wyoming' with revid: 1177967878
# ORES scores for 'Guernsey, Wyoming' with revid: 1166180183
# ORES scores for 'Hanna, Wyoming' with revid: 1166342784
# ORES scores for 'Hartville, Wyoming' with revid: 1166180658
# ORES scores for 'Hudson, Wyoming' with revid: 1166181504
# ORES scores for 'Hulett, Wyoming' with revid: 1174346280
# ORES scores for 'Jackson, Wyoming' with revid: 1180050021
# ORES scores for 'Kaycee, Wyoming' with revid: 1166182166
# ORES scores for 'Kemmerer, Wyoming' with revid: 1176924654
# ORES scores for 'Kirby, Wyoming' with revid: 1166182503
# ORES scores for 'La Barge, Wyoming' with revid: 1166845769
# ORES scores for 'La Grange, Wyoming' with revid: 1108621096
# ORES scores for 'Lander, Wyoming' with revid: 1178457860
# ORES scores for 'Laramie, Wyoming' with revid: 1179834802
# ORES scores for 'Lingle, Wyoming' with revid: 1166206052
# ORES scores for 'Lost Springs, Wyoming' with revid: 1180185126
# ORES scores for 'Lovell, Wyoming' with revid: 1172969664
# ORES scores for 'Lusk, Wyoming' with revid: 1173063550
# ORES scores for 'Lyman, Wyoming' with revid: 1166206538
# ORES scores for 'Manderson, Wyoming' with revid: 1176270613
# ORES scores for 'Manville, Wyoming' with revid: 1168002981
# ORES scores for 'Marbleton, Wyoming' with revid: 1174007159
# ORES scores for 'Medicine Bow, Wyoming' with revid: 1180251311
# ORES scores for 'Meeteetse, Wyoming' with revid: 1166207463
# ORES scores for 'Midwest, Wyoming' with revid: 1166207771
# ORES scores for 'Mills, Wyoming' with revid: 1166207945
# ORES scores for 'Moorcroft, Wyoming' with revid: 1166208485
# ORES scores for 'Mountain View, Wyoming' with revid: 1166208816
# ORES scores for 'Newcastle, Wyoming' with revid: 1145675206
# ORES scores for 'Opal, Wyoming' with revid: 1166845749
# ORES scores for 'Pavillion, Wyoming' with revid: 1166211025
# ORES scores for 'Pine Bluffs, Wyoming' with revid: 1177665506
# ORES scores for 'Pinedale, Wyoming' with revid: 1177672635
# ORES scores for 'Pine Haven, Wyoming' with revid: 1166211365
# ORES scores for 'Powell, Wyoming' with revid: 1169867240
# ORES scores for 'Ranchester, Wyoming' with revid: 1166229572
# ORES scores for 'Rawlins, Wyoming' with revid: 1177981349
# ORES scores for 'Riverside, Wyoming' with revid: 1166230038
# ORES scores for 'Riverton, Wyoming' with revid: 1179837028
# ORES scores for 'Rock River, Wyoming' with revid: 1179127060
# ORES scores for 'Rock Springs, Wyoming' with revid: 1168738433
# ORES scores for 'Rolling Hills, Wyoming' with revid: 1166230195
# ORES scores for 'Saratoga, Wyoming' with revid: 1172694539
# ORES scores for 'Sheridan, Wyoming' with revid: 1179836908
# ORES scores for 'Shoshoni, Wyoming' with revid: 1166347258
# ORES scores for 'Sinclair, Wyoming' with revid: 1162125136
# ORES scores for 'Star Valley Ranch, Wyoming' with revid: 1166752249
# ORES scores for 'Sundance, Wyoming' with revid: 1166330861
# ORES scores for 'Superior, Wyoming' with revid: 1166330907
# ORES scores for 'Ten Sleep, Wyoming' with revid: 1173313467
# ORES scores for 'Thayne, Wyoming' with revid: 1166846273
# ORES scores for 'Thermopolis, Wyoming' with revid: 1180357087
# ORES scores for 'Torrington, Wyoming' with revid: 1171948527
# ORES scores for 'Upton, Wyoming' with revid: 1166331959
# ORES scores for 'Van Tassell, Wyoming' with revid: 1180185427
# ORES scores for 'Wamsutter, Wyoming' with revid: 1169591845
# ORES scores for 'Wheatland, Wyoming' with revid: 1176370621
# ORES scores for 'Worland, Wyoming' with revid: 1166347917
# ORES scores for 'Wright, Wyoming' with revid: 1166334449
# ORES scores for 'Yoder, Wyoming' with revid: 1171182284

# %%
ores_scores_df['ORES_prediction']=0

# %%
# Extract 'prediction' values using list comprehension
predictions = []
for i, row in ores_scores_df.iterrows():
    try:
        prediction = row['ORES_score'][0]['enwiki']['scores'][str(row['Revision_ID'])]['articlequality']['score']['prediction']
        predictions.append(prediction)
    except (KeyError, TypeError):
        # Handle missing or inconsistent data gracefully
        predictions.append(None)  # Or any default value you prefer for invalid entries

# Assign the 'predictions' list to a new column in the DataFrame
ores_scores_df['ORES_Prediction'] = predictions

# %%
ores_scores_df.head(5)
# Out:
#   Revision_ID                                         ORES_score  \
# 0  1171163550  [{'enwiki': {'models': {'articlequality': {'ve...
# 1  1177621427  [{'enwiki': {'models': {'articlequality': {'ve...
# 2  1168359898  [{'enwiki': {'models': {'articlequality': {'ve...
# 3  1165909508  [{'enwiki': {'models': {'articlequality': {'ve...
# 4  1179139816  [{'enwiki': {'models': {'articlequality': {'ve...
#
#   ORES_Prediction
# 0               C
# 1               C
# 2               C
# 3              GA
# 4               C

# %% [markdown]
# ### Step 3: Combining all datasets

# %% [markdown]
# Retrieving State column.

# %%
city_wiki_df=city_wiki_df.merge(cities_df,how='left',left_on='Title',right_on='page_title')

# %%
city_wiki_df.drop(columns=['state_x','state_y','url_x','url_y','page_title_x','page_title_y'],inplace=True)
city_wiki_df.head(5)
# Out:
#                  City  PageID               Title  LatestRevisionid  \
# 0  Abbeville, Alabama  104730  Abbeville, Alabama        1171163550
# 1  Abbeville, Alabama  104730  Abbeville, Alabama        1171163550
# 2  Abbeville, Alabama  104730  Abbeville, Alabama        1171163550
# 3  Abbeville, Alabama  104730  Abbeville, Alabama        1171163550
# 4  Abbeville, Alabama  104730  Abbeville, Alabama        1171163550
#
#   ORES_Score    state
# 0          0  Alabama
# 1          0  Alabama
# 2          0  Alabama
# 3          0  Alabama
# 4          0  Alabama

# %% [markdown]
# Cleaning up population data

# %%
# dropping all rows having null/NaN in them 
population_df.dropna(axis=0, inplace=True)

# Keeping only required columns
population_df_final=population_df.loc[:,['State','Pop_estimate_july2022']]
population_df_final.head(5)
# Out:
#         State  Pop_estimate_july2022
# 0     Alabama              5074296.0
# 1      Alaska               733583.0
# 2     Arizona              7359197.0
# 3    Arkansas              3045637.0
# 4  California             39029342.0

# %% [markdown]
# Joining Population data with city wiki data.

# %%
city_wiki_df=city_wiki_df.merge(population_df_final,how='left',left_on='state',right_on='State')

# %%
city_wiki_df.drop(columns=['State'],inplace=True)

# %%
# Final population data merged with wiki data

city_wiki_df.head(-10)
# Out:
#        index                        City  PageID                       Title  \
# 0          0          Abbeville, Alabama  104730          Abbeville, Alabama
# 1          8         Adamsville, Alabama  104761         Adamsville, Alabama
# 2         16            Addison, Alabama  105188            Addison, Alabama
# 3         24              Akron, Alabama  104726              Akron, Alabama
# 4         32          Alabaster, Alabama  105109          Alabaster, Alabama
# ...      ...                         ...     ...                         ...
# 18148  22957           Sinclair, Wyoming  140079           Sinclair, Wyoming
# 18149  22958  Star Valley Ranch, Wyoming  140145  Star Valley Ranch, Wyoming
# 18150  22959           Sundance, Wyoming  140089           Sundance, Wyoming
# 18151  22960           Superior, Wyoming  140218           Superior, Wyoming
# 18152  22961          Ten Sleep, Wyoming  140241          Ten Sleep, Wyoming
#
#        LatestRevisionid ORES_Score  Pop_estimate_july2022            Division  \
# 0            1171163550          C              5074296.0  East South Central
# 1            1177621427          0              5074296.0  East South Central
# 2            1168359898          0              5074296.0  East South Central
# 3            1165909508          0              5074296.0  East South Central
# 4            1179139816          0              5074296.0  East South Central
# ...                 ...        ...                    ...                 ...
# 18148        1162125136          0               581381.0            Mountain
# 18149        1166752249          0               581381.0            Mountain
# 18150        1166330861          0               581381.0            Mountain
# 18151        1166330907          0               581381.0            Mountain
# 18152        1173313467          0               581381.0            Mountain
#
#          State
# 0      Alabama
# 1      Alabama
# 2      Alabama
# 3      Alabama
# 4      Alabama
# ...        ...
# 18148  Wyoming
# 18149  Wyoming
# 18150  Wyoming
# 18151  Wyoming
# 18152  Wyoming
#
# [18153 rows x 9 columns]

# %% [markdown]
# Next we will merge Division data from Region into the city wiki dataframe.
# We had previously loaded the Region data into a json file : region_df.json. Let us load that back into a dataframe.

# %%
with open('/Users/sayo/Documents/Projects/Home-Projects/Human-Centered-Data-Science/data-512-homework_2/staging_outputs/region_df.json', "r") as read_content: 
    region_data_json=json.load(read_content)

region_data_json
# Out:
# {'Northeast': {'New England': ['Connecticut',
#    'Maine',
#    'Massachusetts',
#    'New Hampshire',
#    'Rhode Island',
#    'Vermont'],
#   'Middle Atlantic': ['New Jersey', 'New York', 'Pennsylvania']},
#  'Midwest': {'East North Central': ['Illinois',
#    'Indiana',
#    'Michigan',
#    'Ohio',
#    'Wisconsin'],
#   'West North Central': ['Iowa',
#    'Kansas',
#    'Minnesota',
#    'Missouri',
#    'Nebraska',
#    'North Dakota',
#    'South Dakota']},
#  'South': {'South Atlantic': ['Delaware',
#    'Florida',
#    'Georgia',
#    'Maryland',
#    'North Carolina',
#    'South Carolina',
#    'Virginia',
#    'West Virginia'],
#   'East South Central': ['Alabama', 'Kentucky', 'Mississippi', 'Tennessee'],
#   'West South Central': ['Arkansas', 'Louisiana', 'Oklahoma', 'Texas']},
#  'West': {'Mountain': ['Arizona',
#    'Colorado',
#    'Idaho',
#    'Montana',
#    'Nevada',
#    'New Mexico',
#    'Utah',
#    'Wyoming'],
#   'Pacific': ['Alaska', 'California', 'Hawaii', 'Oregon', 'Washington']}}

# %%
region_data=[]
for division, states in region_data_json["Northeast"].items():
    for state in states:
       region_data.append({"Division": division, "State": state})

for division, states in region_data_json["Midwest"].items():
    for state in states:
        region_data.append({"Division": division, "State": state})

for division, states in region_data_json["South"].items():
    for state in states:
       region_data.append({"Division": division, "State": state})

for division, states in region_data_json["West"].items():
    for state in states:
       region_data.append({"Division": division, "State": state})

region_data_df=pd.DataFrame(region_data)
region_data_df
# Out:
#               Division           State
# 0          New England     Connecticut
# 1          New England           Maine
# 2          New England   Massachusetts
# 3          New England   New Hampshire
# 4          New England    Rhode Island
# 5          New England         Vermont
# 6      Middle Atlantic      New Jersey
# 7      Middle Atlantic        New York
# 8      Middle Atlantic    Pennsylvania
# 9   East North Central        Illinois
# 10  East North Central         Indiana
# 11  East North Central        Michigan
# 12  East North Central            Ohio
# 13  East North Central       Wisconsin
# 14  West North Central            Iowa
# 15  West North Central          Kansas
# 16  West North Central       Minnesota
# 17  West North Central        Missouri
# 18  West North Central        Nebraska
# 19  West North Central    North Dakota
# 20  West North Central    South Dakota
# 21      South Atlantic        Delaware
# 22      South Atlantic         Florida
# 23      South Atlantic         Georgia
# 24      South Atlantic        Maryland
# 25      South Atlantic  North Carolina
# 26      South Atlantic  South Carolina
# 27      South Atlantic        Virginia
# 28      South Atlantic   West Virginia
# 29  East South Central         Alabama
# 30  East South Central        Kentucky
# 31  East South Central     Mississippi
# 32  East South Central       Tennessee
# 33  West South Central        Arkansas
# 34  West South Central       Louisiana
# 35  West South Central        Oklahoma
# 36  West South Central           Texas
# 37            Mountain         Arizona
# 38            Mountain        Colorado
# 39            Mountain           Idaho
# 40            Mountain         Montana
# 41            Mountain          Nevada
# 42            Mountain      New Mexico
# 43            Mountain            Utah
# 44            Mountain         Wyoming
# 45             Pacific          Alaska
# 46             Pacific      California
# 47             Pacific          Hawaii
# 48             Pacific          Oregon
# 49             Pacific      Washington

# %% [markdown]
# Combining city Wiki data and Division data

# %%
city_wiki_df=city_wiki_df.merge(region_data_df,left_on='state',right_on='State')

# %%
city_wiki_df.drop(columns=['City','PageID'],inplace=True)

# %%
# dropping duplicates if any
city_wiki_df = city_wiki_df.drop_duplicates()

# %%
#Renaming columns

city_wiki_df=city_wiki_df.rename(columns={"Title":"Article_Title",
                             "LatestRevisionid":"Revision_ID",
                             "ORES_Score":"article_quality",
                             "Pop_estimate_july2022":"population",
                             "Division":"Regional_division"
                             })

# %%
city_wiki_df=city_wiki_df.reindex(columns=['State','Regional_division','population','Article_Title','Revision_ID','article_quality'])
city_wiki_df.to_csv("wp_scored_city_articles_by_state.csv",index=False)

# %% [markdown]
# Combining ORES score with rest of the data

# %%
city_wiki_df=city_wiki_df.merge(ores_scores_df,how='left',left_on='Revision_ID',right_on='Revision_ID')

# %%
city_wiki_df.drop(columns=['article_quality','ORES_score'],inplace=True)

# %%
city_wiki_df.rename(columns={'ORES_Prediction':'article_quality'},inplace=True)

# %%
city_wiki_df.head(5)
# Out:
#      State   Regional_division  population        Article_Title Revision_ID  \
# 0  Alabama  East South Central   5074296.0   Abbeville, Alabama  1171163550
# 1  Alabama  East South Central   5074296.0  Adamsville, Alabama  1177621427
# 2  Alabama  East South Central   5074296.0     Addison, Alabama  1168359898
# 3  Alabama  East South Central   5074296.0       Akron, Alabama  1165909508
# 4  Alabama  East South Central   5074296.0   Alabaster, Alabama  1179139816
#
#   article_quality
# 0               C
# 1               C
# 2               C
# 3              GA
# 4               C

# %%
city_wiki_df.to_csv("wp_scored_city_articles_by_state.csv",index=False)

# %% [markdown]
# ### Step 4 + 5 : Analysis and Results
#
# We need to calculate total-articles-per-population (a ratio representing the number of articles per person)  and high-quality-articles-per-population (a ratio representing the number of high quality articles per person) on a state-by-state and divisional basis. All of these values are “per capita” ratios.
#
# For this analysis we will consider "high quality" articles to be articles that ORES predicted would be in either the "FA" (featured article) or "GA" (good article) classes

# %% [markdown]
# ##### Top 10 US states by coverage: The 10 US states with the highest total articles per capita (in descending order) .

# %%
analysis_1_df=pd.read_csv('/Users/sayo/Documents/Projects/Home-Projects/Human-Centered-Data-Science/data-512-homework_2/final_outputs/wp_scored_city_articles_by_state.csv')
analysis_1_df
#analysis_1_df.groupby('State').count()

# Calculate total articles per state
total_articles_per_state = analysis_1_df.groupby('State')['Revision_ID'].count().reset_index()
total_articles_per_state.columns = ['State', 'Total_Articles']

# Calculate total population per state
total_population_per_state = analysis_1_df.groupby('State')['population'].max().reset_index()

# Merge the total articles and total population DataFrames
merged_df = pd.merge(total_articles_per_state, total_population_per_state, on='State')

# Calculate articles per population
merged_df['Articles_Per_Population'] = merged_df['Total_Articles'] / merged_df['population']

# Get top 10 states with highest articles per population
top_10_states_by_coverage = merged_df.nlargest(10, 'Articles_Per_Population')

# Print the top 10 states
print(top_10_states_by_coverage[['State', 'Articles_Per_Population']])
# Out:
#            State  Articles_Per_Population
# 32       Vermont                 0.000508
# 16         Maine                 0.000349
# 12          Iowa                 0.000326
# 1         Alaska                 0.000203
# 28  Pennsylvania                 0.000197
# 19      Michigan                 0.000177
# 36       Wyoming                 0.000170
# 3       Arkansas                 0.000164
# 22      Missouri                 0.000154
# 20     Minnesota                 0.000149

# %% [markdown]
# ##### Bottom 10 US states by coverage: The 10 US states with the lowest total articles per capita (in ascending order) .

# %%
# Get bottom 10 states with highest articles per population
bottom_10_states_by_coverage=merged_df.nsmallest(10, 'Articles_Per_Population')

# Print the bottom 10 states
print(bottom_10_states_by_coverage[['State', 'Articles_Per_Population']])
# Out:
#          State  Articles_Per_Population
# 24      Nevada                 0.000006
# 4   California                 0.000012
# 2      Arizona                 0.000012
# 33    Virginia                 0.000015
# 7      Florida                 0.000019
# 26    Oklahoma                 0.000019
# 13      Kansas                 0.000021
# 17    Maryland                 0.000025
# 35   Wisconsin                 0.000033
# 34  Washington                 0.000036

# %% [markdown]
# ##### Top 10 US states by high quality: The 10 US states with the highest high quality articles per capita (in descending order)

# %%
analysis_2_df=pd.read_csv('/Users/sayo/Documents/Projects/Home-Projects/Human-Centered-Data-Science/data-512-homework_2/final_outputs/wp_scored_city_articles_by_state.csv')

cities_with_high_quality_articles=analysis_2_df[(analysis_2_df['article_quality']=='FA') |
                                                (analysis_2_df['article_quality']=='GA')]



# Calculate total articles per state
total_hq_articles_per_state = cities_with_high_quality_articles.groupby('State')['Revision_ID'].count().reset_index()
total_hq_articles_per_state.columns = ['State', 'Total_high_quality_Articles']

# Calculate total population per state
total_population_per_state = cities_with_high_quality_articles.groupby('State')['population'].max().reset_index()

# Merge the total articles and total population DataFrames
merged_df2 = pd.merge(total_hq_articles_per_state, total_population_per_state, on='State')

# Calculate articles per population
merged_df2['HQ_Articles_Per_Population'] = merged_df2['Total_high_quality_Articles'] / merged_df2['population']

# Get top 10 states with highest articles per population
top_10_states_by_coverage = merged_df2.nlargest(10, 'HQ_Articles_Per_Population')

# Print the top 10 states
print(top_10_states_by_coverage[['State', 'HQ_Articles_Per_Population']])
# Out:
#         State  HQ_Articles_Per_Population
# 26    Wyoming                    0.000067
# 16    Montana                    0.000049
# 15   Missouri                    0.000043
# 1      Alaska                    0.000042
# 11       Iowa                    0.000033
# 20     Oregon                    0.000033
# 13  Minnesota                    0.000030
# 6    Delaware                    0.000025
# 3    Arkansas                    0.000024
# 9       Idaho                    0.000021

# %% [markdown]
# ##### Bottom 10 US states by high quality: The 10 US states with the lowest high quality articles per capita (in ascending order)

# %%
#Get bottom 10 states with highest articles per population
bottom_10_states_by_coverage=merged_df2.nsmallest(10, 'HQ_Articles_Per_Population')

# Print the bottom 10 states
print(bottom_10_states_by_coverage[['State', 'HQ_Articles_Per_Population']])
# Out:
#            State  HQ_Articles_Per_Population
# 21  Pennsylvania                    0.000001
# 17        Nevada                    0.000003
# 2        Arizona                    0.000003
# 4     California                    0.000004
# 7        Florida                    0.000005
# 19      Oklahoma                    0.000008
# 10      Illinois                    0.000009
# 12      Michigan                    0.000010
# 0        Alabama                    0.000010
# 25     Wisconsin                    0.000011

# %% [markdown]
# ##### Census divisions by total coverage: A rank ordered list of US census divisions (in descending order) by total articles per capita

# %% [markdown]
# ##### Census divisions by high quality coverage: Rank ordered list of US census divisions (in descending order) by high quality articles per capita
